# %% [markdown]
# ## Connect to your Google Drive or any filesystem you are going to use.

# %%
import sys
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules
if IN_COLAB:
    from google.colab import drive

    drive.mount("/content/gdrive")
base_path = (
    Path("your_path") if IN_COLAB else Path(".")
)

#Fix if you want to use a different path
output_path = base_path / "output"
data_path = base_path / "HaluEval"
output_path.mkdir(exist_ok=True)

# %% [markdown]
# ## Put here the file system where you are going to work. However you should have there the cloned repositories of:
#
# - https://github.com/RUCAIBox/HaluEval.git
#
# It is enough with having access to the data folder of the HaluEvalRepository.

# %% [markdown]
# ## These are the libraries needed to run this notebook

# %% [markdown]
# ## Deep Learning Installations

# %%
# %pip install transformers datasets evaluate rouge_score
# %pip install --upgrade huggingface_hub
# %pip install accelerate -U
# %pip install transformers[torch]
# %pip install sentencepiece
# %pip install google
# %pip install protobuf
# Out:
# Requirement already satisfied: transformers in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (4.39.0)
# Requirement already satisfied: datasets in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (2.18.0)
# Requirement already satisfied: evaluate in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: rouge_score in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: pyyaml>=5.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: numpy>=1.17 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: requests in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: filelock in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: tqdm>=4.27 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: packaging>=20.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers) (24.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers) (0.15.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from datasets) (15.0.2)
# Requirement already satisfied: aiohttp in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from datasets) (3.9.3)
# Requirement already satisfied: xxhash in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from datasets) (2.2.1)
# Requirement already satisfied: pyarrow-hotfix in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from datasets) (2024.2.0)
# Requirement already satisfied: responses<0.19 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: absl-py in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from rouge_score) (2.1.0)
# Requirement already satisfied: nltk in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: frozenlist>=1.1.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: click in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from nltk->rouge_score) (1.3.2)
# Requirement already satisfied: tzdata>=2022.7 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/data/yeroj/.venv/hallu/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: huggingface_hub in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (0.22.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface_hub) (2024.2.0)
# Requirement already satisfied: packaging>=20.9 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface_hub) (24.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface_hub) (4.10.0)
# Requirement already satisfied: tqdm>=4.42.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface_hub) (4.66.2)
# Requirement already satisfied: pyyaml>=5.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: filelock in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface_hub) (3.13.1)
# Requirement already satisfied: requests in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: certifi>=2017.4.17 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->huggingface_hub) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->huggingface_hub) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->huggingface_hub) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->huggingface_hub) (3.3.2)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/data/yeroj/.venv/hallu/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: accelerate in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (0.21.0)
# Collecting accelerate
#   Using cached accelerate-0.29.2-py3-none-any.whl (297 kB)
# Requirement already satisfied: numpy>=1.17 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: pyyaml in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: safetensors>=0.3.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: huggingface-hub in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from accelerate) (0.22.2)
# Requirement already satisfied: torch>=1.10.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from accelerate) (2.2.1)
# Requirement already satisfied: fsspec in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2024.2.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: networkx in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (4.10.0)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.19.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: sympy in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: filelock in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: triton==2.2.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Requirement already satisfied: jinja2 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.4.99)
# Requirement already satisfied: requests in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.21.0
#     Uninstalling accelerate-0.21.0:
#       Successfully uninstalled accelerate-0.21.0
# Successfully installed accelerate-0.29.2
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/data/yeroj/.venv/hallu/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers[torch] in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (4.39.0)
# Requirement already satisfied: packaging>=20.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (24.0)
# Requirement already satisfied: filelock in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (3.13.1)
# Requirement already satisfied: tqdm>=4.27 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (4.66.2)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (0.15.2)
# Requirement already satisfied: requests in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (2.31.0)
# Requirement already satisfied: numpy>=1.17 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (1.26.4)
# Requirement already satisfied: safetensors>=0.4.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (0.4.2)
# Requirement already satisfied: pyyaml>=5.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (2023.12.25)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: torch in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (2.2.1)
# Requirement already satisfied: accelerate>=0.21.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from transformers[torch]) (0.29.2)
# Requirement already satisfied: psutil in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (4.10.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers[torch]) (2024.2.0)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: networkx in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (3.2.1)
# Requirement already satisfied: triton==2.2.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (2.2.0)
# Requirement already satisfied: jinja2 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (3.1.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: sympy in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (1.12)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (8.9.2.26)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from torch->transformers[torch]) (2.19.3)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch]) (12.4.99)
# Requirement already satisfied: charset-normalizer<4,>=2 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->transformers[torch]) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->transformers[torch]) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from requests->transformers[torch]) (3.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from sympy->torch->transformers[torch]) (1.3.0)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/data/yeroj/.venv/hallu/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sentencepiece in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (0.2.0)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/data/yeroj/.venv/hallu/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from google) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (from beautifulsoup4->google) (2.5)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/data/yeroj/.venv/hallu/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: protobuf in /data/yeroj/.venv/hallu/lib/python3.10/site-packages (5.26.0)
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the '/data/yeroj/.venv/hallu/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Libraries

# %%
from datasets import load_dataset
from datasets import Dataset
from transformers import AutoTokenizer
from transformers import DataCollatorForSeq2Seq
from transformers import pipeline
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM
import numpy as np
import pandas as pd
import evaluate

# %% [markdown]
# # Reading Dataset
#
# `The method loadDataset receieves the path where the datasets json files of the HaluEval repository are. You just need to pass your path and the name of the dataset you are going to use.`
#
# ## Dataset Names:
# - summarization
# - dialogue
# - qa
# - general

# %%
## As a recomendation keep these two with the same naming if you do not want to change many things
datasetName = "qa"
task = datasetName

# %%
def loadDataset(path="./data", datasetName="qa"):
    data = pd.read_json(
        data_path / (path + "/" + datasetName + "_data.json"), lines=True
    )
    return data

# %% [markdown]
# ## For this particular example we are loading the qa_data.json since is the one that takes the less time to process in case you want to test quickly how it works.

# %%
data = loadDataset(datasetName=datasetName)

# %%
data.head()
# Out:
#                                            knowledge  \
# 0  Iron Man is starring Robert Downey Jr.Robert D...
# 1  The Secret Life of Bees has genre Teen drama. ...
# 2  Michael Jackson wrote Dancing the DreamDancing...
# 3   Dead to the World is written by Charlaine Harris
# 4  Ryan Reynolds starred in TurboTurbo is starrin...
#
#                                     dialogue_history  \
# 0  [Human]: Do you like Iron Man [Assistant]: Sur...
# 1  [Human]: Could you recommend any books like Th...
# 2  [Human]: Do you like Michael Jackson? [Assista...
# 3  [Human]: Could you recommend books similar to ...
# 4  [Human]: Could you recommend a good movie with...
#
#                                       right_response  \
# 0  I like crime fiction! Didn't know RDJ was in t...
# 1  yes and he also produced White Oleander and it...
# 2  Yes, Healing the World is one of my favorite s...
# 3  Do you like this book because of it's author C...
# 4                       Yep. As well as Ben Schwartz
#
#                                hallucinated_response
# 0  I'm not a fan of crime movies, but I did know ...
# 1  No, I don't think Hunt Lowry was involved in A...
# 2  Absolutely. In addition to winning the Grammy ...
# 3  Do you like this book because of its author St...
# 4  Actually, Snoop Dog wasn't in Turbo. But you s...

# %%
len(data)
# Out:
# 10000

# %% [markdown]
# # Setting Device to use the GPU
#
# We use the T4 GPU in Colab since the heaviest computation for us is the inference of the LLM-Evaluator. Therefore, T4 seem as the better fit.

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA L40S

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Generic LLMModel class to reuse the functionality of extracting the features.

# %%
from transformers import BartForConditionalGeneration, BartTokenizer
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import BartForConditionalGeneration, PegasusForConditionalGeneration
from transformers import LEDForConditionalGeneration, LEDTokenizer
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from transformers import LlamaForCausalLM, LlamaTokenizer

import torch
import torch.nn.functional as F


class LLMModel:
    def __init__(self):
        # if self.model_name != 'google/gemma-7b-it':
        self.model = self.model.to(device)
        pass

    def getName(self) -> str:
        return self.model_name

    def getSanitizedName(self) -> str:
        return self.model_name.replace("/", "__")

    def generate(self, inpt):
        pass

    ##Move in future commits this method to an utils.py
    def truncate_string_by_len(self, s, truncate_len):
        words = s.split()
        truncated_words = words[:-truncate_len] if truncate_len > 0 else words
        return " ".join(truncated_words)

    # Method to get the vocabulary probabilities of the LLM for a given token on the generated text from LLM-Generator
    def getVocabProbsAtPos(self, pos, token_probs):
        sorted_probs, sorted_indices = torch.sort(token_probs[pos, :], descending=True)
        return sorted_probs

    def getMaxLength(self):
        return self.model.config.max_position_embeddings

    # By default knowledge is the empty string. If you want to add extra knowledge you can do it like in the cases of the qa_data.json and dialogue_data.json
    def extractFeatures(
        self,
        knowledge="",
        conditionted_text="",
        generated_text="",
        features_to_extract={},
    ):
        self.model.eval()

        total_len = len(knowledge) + len(conditionted_text) + len(generated_text)
        truncate_len = min(total_len - self.tokenizer.model_max_length, 0)

        # Truncate knowledge in case is too large
        knowledge = self.truncate_string_by_len(knowledge, truncate_len // 2)
        # Truncate text_A in case is too large
        conditionted_text = self.truncate_string_by_len(
            conditionted_text, truncate_len - (truncate_len // 2)
        )

        inputs = self.tokenizer(
            [knowledge + conditionted_text + generated_text],
            return_tensors="pt",
            max_length=self.getMaxLength(),
            truncation=True,
        )

        for key in inputs:
            inputs[key] = inputs[key].to(device)

        with torch.no_grad():
            outputs = self.model(**inputs)
            logits = outputs.logits

        probs = F.softmax(logits, dim=-1)
        probs = probs.to(device)

        tokens_generated_length = len(self.tokenizer.tokenize(generated_text))
        start_index = logits.shape[1] - tokens_generated_length
        conditional_probs = probs[0, start_index :]

        token_ids_generated = inputs["input_ids"][0, start_index :].tolist()
        token_probs_generated = [
            conditional_probs[i, tid].item()
            for i, tid in enumerate(token_ids_generated)
        ]

        tokens_generated = self.tokenizer.convert_ids_to_tokens(token_ids_generated)

        minimum_token_prob = min(token_probs_generated)
        average_token_prob = sum(token_probs_generated) / len(token_probs_generated)

        maximum_diff_with_vocab = -1
        minimum_vocab_extreme_diff = 100000000000

        if features_to_extract["MDVTP"] == True or features_to_extract["MMDVP"] == True:
            size = len(token_probs_generated)
            for pos in range(size):
                vocabProbs = self.getVocabProbsAtPos(pos, conditional_probs)
                maximum_diff_with_vocab = max(
                    [
                        maximum_diff_with_vocab,
                        self.getDiffVocab(vocabProbs, token_probs_generated[pos]),
                    ]
                )
                minimum_vocab_extreme_diff = min(
                    [
                        minimum_vocab_extreme_diff,
                        self.getDiffMaximumWithMinimum(vocabProbs),
                    ]
                )

        # allFeatures = [minimum_token_prob, average_token_prob, maximum_diff_with_vocab, minimum_vocab_extreme_diff]

        allFeatures = {
            "mtp": minimum_token_prob,
            "avgtp": average_token_prob,
            "MDVTP": maximum_diff_with_vocab,
            "MMDVP": minimum_vocab_extreme_diff,
        }

        selectedFeatures = {}
        for key, feature in features_to_extract.items():
            if feature == True:
                selectedFeatures[key] = allFeatures[key]

        return selectedFeatures

    def getDiffVocab(self, vocabProbs, tprob):
        return (vocabProbs[0] - tprob).item()

    def getDiffMaximumWithMinimum(self, vocabProbs):
        return (vocabProbs[0] - vocabProbs[-1]).item()

# %% [markdown]
# ## Definition of the specific Models

# %%
class Gemma(LLMModel):
    def __init__(self):
        self.model_name = "google/gemma-7b-it"
        self.model = AutoModelForCausalLM.from_pretrained(
            self.model_name
        )
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class LLama(LLMModel):
    def __init__(self):
        self.model_name = "meta-llama/Llama-2-7b-chat-hf"
        self.model = AutoModelForCausalLM.from_pretrained(
            self.model_name,
        )
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=1024, return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary


class Opt(LLMModel):
    def __init__(self):
        self.model_name = "facebook/opt-6.7b"
        self.model = AutoModelForCausalLM.from_pretrained(self.model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()
 
 
    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])
 
        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)
 
        return summary


class Gptj(LLMModel):
    def __init__(self):
        self.model_name = "EleutherAI/gpt-j-6B"
        self.model = AutoModelForCausalLM.from_pretrained(self.model_name)
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name)
        super().__init__()
 
 
    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])
 
        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)
 
        return summary


class BartCNN(LLMModel):
    def __init__(self):
        self.model_name = "facebook/bart-large-cnn"
        self.model = BartForConditionalGeneration.from_pretrained(self.model_name)
        self.tokenizer = BartTokenizer.from_pretrained(self.model_name)
        super().__init__()


    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary

class GPT2Generator(LLMModel):
    def __init__(self):
        self.model_name = "gpt2-large"
        self.model = GPT2LMHeadModel.from_pretrained(self.model_name)
        self.tokenizer = GPT2Tokenizer.from_pretrained(self.model_name)
        super().__init__()

    def generate(self, inpt):
        inputs = self.tokenizer.encode(
            inpt, return_tensors="pt", max_length=self.getMaxLength(), truncation=True
        )
        output_ids = self.model.generate(
            inputs, max_length=1024, num_return_sequences=1
        )
        output = self.tokenizer.decode(output_ids[0], skip_special_tokens=True)
        return output


class LED(LLMModel):
    def __init__(self):
        self.model_name = "allenai/led-large-16384-arxiv"
        self.model = LEDForConditionalGeneration.from_pretrained(self.model_name)
        self.tokenizer = LEDTokenizer.from_pretrained(self.model_name)
        super().__init__()

    def generate(self, inpt):
        inputs = self.tokenizer(
            [inpt], max_length=self.getMaxLength(), return_tensors="pt", truncation=True
        )
        summary_ids = self.model.generate(inputs["input_ids"])

        summary = self.tokenizer.decode(summary_ids[0], skip_special_tokens=True)

        return summary

# %% [markdown]
# # The Dictionary `features_to_extract` defines which features will be use in this experiment.
#
# ## Features Meaning:
#
# - `mtp` : Take the minimum of the probabilities that the LLM_E gives to the tokens on the generated-text.
# - `avgtp` : Take the average of the probabilities that the LLM_E
# gives to the tokens on the generated-text.
# - `MDVTP` : Take the maximum from all the differences
# between the token with the highest probability
# according to LLM_E at position i and the
# assigned probability from LLM_E to the token at position i in the generated_text.
# - `MMDVP` : Take the maximum from all the differences between the token with the highest probability according to $LLM_E$ at position $i$ ($v^*$) and the token with the lowest probability according to $LLM_E$ at position $i$ ($v^-$).

# %%
feature_to_extract = 'mtp'

available_features_to_extract = ["mtp", "avgtp", "MDVTP", "MMDVP"]
if feature_to_extract == 'all':
    features_to_extract = {
        feature: True for feature in available_features_to_extract
    }
else:
    features_to_extract = {
        feature: True if feature == feature_to_extract else False
        for feature in available_features_to_extract
    }

features_to_extract
# Out:
# {'mtp': True, 'avgtp': False, 'MDVTP': False, 'MMDVP': False}

# %% [markdown]
# ## Cleaning Cache on GPU to save memory

# %%
import torch
import gc

gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## This cell is to instantiate the model you intend to use for the experiment

# %%
model = BartCNN()
# model = LED()
# model = GPT2Generator()
# model = LLama()
# model = Gemma()
# model = Opt()
# model = Gptj()

# %% [markdown]
# ## This cell creates the dataset separation of `10%` for training and `90%` for testing depending on what task you are addressing. The following explanation is what happens if summarization is the task used. But the same explanation applies to all tasks and also you cand pass as parameter how many data points you want to include in training.
#
# ## Example: The data is separated on 2000 (1000 of document with right summary and 1000 with the same document but with the hallucinated summary). The rest which is 18000 is used to for testing.
#
# ### As expected from previous cells the task string expected are:
# - `summarization`
# - `qa`
# - `dialogue`
# - `general`

# %%
import random


# Load the data depending on the task
def loadRowData(taskName, row, includeKnowledge=False):
    if taskName == "summarization":
        return "", row["document"], row["right_summary"], row["hallucinated_summary"]
    elif taskName == "qa":
        if includeKnowledge:
            return (
                row["knowledge"],
                row["question"],
                row["right_answer"],
                row["hallucinated_answer"],
            )
        else:
            return "", row["question"], row["right_answer"], row["hallucinated_answer"]

    elif taskName == "dialogue":
        if includeKnowledge:
            return (
                row["knowledge"],
                row["dialogue_history"],
                row["right_response"],
                row["hallucinated_response"],
            )
        else:
            return (
                "",
                row["dialogue_history"],
                row["right_response"],
                row["hallucinated_response"],
            )

    elif taskName == "general":
        return (
            "",
            row["user_query"],
            row["chatgpt_response"],
            row["hallucination_label"],
        )

    else:
        raise Exception("Task not supported")


# Adapt the dataset to have a data point of conditioned-text with right-generation and another with the same conditioned-text and tha hallucinated answer.
def adaptDataset(data, taskName):
    datasetAdapted = None
    if taskName == "general":
        # There is data point that is filling the <mask> token but that gives error with some LLMs
        datasetAdapted = [
            (
                (knowledge, document, response, 1)
                if hallu == "yes"
                else (knowledge, document, response, 0)
            )
            for knowledge, document, response, hallu in data
            if "<mask>" not in document and "<mask>" not in response
        ]

    elif taskName == "summarization" or taskName == "qa" or taskName == "dialogue":
        datasetAdapted = [
            (knowledge, document, right, 1)
            for knowledge, document, right, hallu in data
        ] + [
            (knowledge, document, hallu, 0)
            for knowledge, document, right, hallu in data
        ]

    else:
        raise Exception("Task not supported")

    random.shuffle(datasetAdapted)
    return datasetAdapted


def splitDataset(
    data: pd.DataFrame,
    taskName: str,
    trainingSize: int,
    valSize: int,
    includeKnowledge=False,
):

    dataset = []
    for _, row in data.iterrows():
        knowledge, text, right, hallu = loadRowData(taskName, row, includeKnowledge)
        dataset.append((knowledge, text, right, hallu))

    random.shuffle(dataset)

    dataset_train = dataset[:trainingSize]  # Take only trainingSize
    dataset_val = (
        []
    )  # dataset[trainingSize:trainingSize + valSize] # Take only trainingSize
    dataset_test = dataset[trainingSize:]  # Take the rest as testing

    datasetAdaptedTrain = adaptDataset(dataset_train, taskName)
    datasetAdaptedValidation = adaptDataset(dataset_val, taskName)
    datasetAdaptedTest = adaptDataset(dataset_test, taskName)

    X_train = [(x, q, y) for x, q, y, _ in datasetAdaptedTrain]
    Y_train = [z for _, _, _, z in datasetAdaptedTrain]

    X_val = [(x, q, y) for x, q, y, _ in datasetAdaptedValidation]
    Y_val = [z for _, _, _, z in datasetAdaptedValidation]

    X_test = [(x, q, y) for x, q, y, _ in datasetAdaptedTest]
    Y_test = [z for _, _, _, z in datasetAdaptedTest]

    return X_train, Y_train, X_val, Y_val, X_test, Y_test

# %%
includeKnowledge = True
includeConditioned = True

# %%
X_train, Y_train, X_val, Y_val, X_test, Y_test = splitDataset(
    data, task, 1000, 0, includeKnowledge=includeKnowledge
)

# %%
print(len(X_train), len(Y_train))
print(len(X_val), len(Y_val))
print(len(X_test), len(Y_test))  # verify the sizes look right
# Out:
# 2000 2000
# 0 0
# 18000 18000

# %% [markdown]
# ## To Save the separation if needed

# %%
train_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_train],
        "Conditioned Text": [x[1] for x in X_train],
        "Generated Text": [x[2] for x in X_train],
        "Label": Y_train,
    }
)

val_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_val],
        "Conditioned Text": [x[1] for x in X_val],
        "Generated Text": [x[2] for x in X_val],
        "Label": Y_val,
    }
)

test_df = pd.DataFrame(
    {
        "Knowledge": [x[0] for x in X_test],
        "Conditioned Text": [x[1] for x in X_test],
        "Generated Text": [x[2] for x in X_test],
        "Label": Y_test,
    }
)

#Export to CSV
if includeKnowledge:
    train_df.to_csv(output_path / (task + '_knowledge_train_data.csv'), index=False)
    test_df.to_csv(output_path / (task + '_knowledge_test_data.csv'), index=False)
else:
    train_df.to_csv(output_path / (task + '_train_data.csv'), index=False)
    val_df.to_csv(output_path / (task + '_val_data.csv'), index=False)
    test_df.to_csv(output_path / (task + '_test_data.csv'), index=False)

# %%
def getXY(df: pd.DataFrame, includeKnowledge=True, includeConditioned=True):
    X = []
    Y = []

    # Iterate over rows using itertuples
    for _, row in df.iterrows():
        x, c, g = (
            row["Knowledge"] if includeKnowledge else "",
            row["Conditioned Text"] if includeConditioned else "",
            row["Generated Text"],
        )
        y = row["Label"]

        # Append values to respective lists
        X.append((x, c, g))
        Y.append(y)
    return X, Y

# %%
X_train, Y_train = getXY(
    train_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)
X_val, Y_val = getXY(
    val_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)
X_test, Y_test = getXY(
    test_df, includeKnowledge=includeKnowledge, includeConditioned=includeConditioned
)

# %%
print(len(X_train), len(Y_train))
print(len(X_val), len(Y_val))
print(len(X_test), len(Y_test))  # verify the sizes look right
# Out:
# 2000 2000
# 0 0
# 18000 18000

# %%
X_test[0]
# Out:
# ('Margaret Mitchell wrote Gone with the Wind. Gone with the Wind has genre Novel',
#  '[Human]: could you recommend some information about Margaret Mithell [Assistant]: I surely will because she is famous for writing the Historical fiction novel, Gone With the Wind. [Human]: so was this written by [Assistant]: There is another one out there you may like, The Lady in the Lake? [Human]: yes this is a novel i see ',
#  'And, if you like novels, you could try reading Fifty Shades of Grey!')

# %%
Y_test[0]
# Out:
# 0

# %% [markdown]
# ## Extracting the features for the Training Data

# %%
import torch
from tqdm import tqdm


def extract_features(
    knowledge: str,
    conditioned_text: str,
    generated_text: str,
    features_to_extract: dict[str, bool],
):
    return model.extractFeatures(
        knowledge, conditioned_text, generated_text, features_to_extract
    )


X_train_features_maps = []
# i = 0

for knowledge, conditioned_text, generated_text in tqdm(X_train, desc="Processing"):
    # print("Extracting: ", i)
    X_train_features_maps.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()  # Clean cache in every step for memory saving.
    # i += 1
# Out:
# Processing: 100%|██████████| 2000/2000 [01:03<00:00, 31.27it/s]

# %%
len(X_train_features_maps)
# Out:
# 2000

# %%
X_train_features_maps[0]
# Out:
# {'mtp': 0.2988438308238983}

# %%
X_train_features = [list(dic.values()) for dic in X_train_features_maps]

# %%
len(X_train_features)
# Out:
# 2000

# %%
X_train_features[0]
# Out:
# [0.2988438308238983]

# %% [markdown]
# ## Training Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(verbose=1)
clf.fit(X_train_features, Y_train)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.93147D-01    |proj g|=  2.24318D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      1     0     0   3.873D-06   6.829D-01
#   F =  0.68290687175045428
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.
# LogisticRegression(verbose=1)

# %% [markdown]
# ## Evaluate accuracy of Logistic Regression on the training set

# %%
from sklearn.metrics import accuracy_score

Y_Pred = clf.predict(X_train_features)

accuracy = accuracy_score(Y_train, Y_Pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 54.10%

# %%
log_odds = clf.coef_[0]
odds = np.exp(clf.coef_[0])
lr_features_log = {k: v for k, v in zip(X_train_features_maps[0].keys(), log_odds)}
lr_features_no_log = {k: v for k, v in zip(X_train_features_maps[0].keys(), odds)}

print("log", lr_features_log)
print("no_log", lr_features_no_log)
# Out:
# log {'mtp': -0.917627619300086}
# no_log {'mtp': 0.39946560232398703}

# %% [markdown]
# ## Extracting the Features of the Validation Set

# %%
X_val_features_map = []

for knowledge, conditioned_text, generated_text in tqdm(X_val, desc="Processing"):
    X_val_features_map.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()
# Out:
# Processing: 0it [00:00, ?it/s]

# %%
X_val_features = [list(dic.values()) for dic in X_val_features_map]

# %% [markdown]
# ## Uncomment nex cell if you have a validation set and you want to see LR accuracy on it.

# %%
# from sklearn.metrics import accuracy_score

# Y_Pred = clf.predict(X_val_features)

# accuracy = accuracy_score(Y_val, Y_Pred)
# print(f"Accuracy: {accuracy * 100:.2f}%")

# %% [markdown]
# ## Extracting the Features of the Test Set

# %%
from tqdm import tqdm

X_test_features_map = []

for knowledge, conditioned_text, generated_text in tqdm(X_test, desc="Processing"):
    X_test_features_map.append(
        extract_features(
            knowledge, conditioned_text, generated_text, features_to_extract
        )
    )
    torch.cuda.empty_cache()
# Out:
# Processing: 100%|██████████| 18000/18000 [09:25<00:00, 31.84it/s]

# %%
X_test_features = [list(dic.values()) for dic in X_test_features_map]

# %% [markdown]
# ## Evaluate accuracy of the LogisticRegression on the testing set

# %%
from sklearn.metrics import accuracy_score

Y_Pred = clf.predict(X_test_features)

lr_accuracy = accuracy_score(Y_test, Y_Pred)
print(f"Accuracy: {lr_accuracy * 100:.2f}%")
# Out:
# Accuracy: 54.19%

# %%
log_odds = clf.coef_[0]
pd.DataFrame(log_odds, X_train_features_maps[0].keys(), columns=["coef"]).sort_values(
    by="coef", ascending=False
)
# Out:
#          coef
# mtp -0.917628

# %%
odds = np.exp(clf.coef_[0])
pd.DataFrame(odds, X_train_features_maps[0].keys(), columns=["coef"]).sort_values(
    by="coef", ascending=False
)
# Out:
#          coef
# mtp  0.399466

# %%
import torch.nn as nn


class SimpleDenseNet(nn.Module):
    def __init__(self, input_dim: int, hidden_dim: int, output_dim=1, dropout_prob=0.3):
        super(SimpleDenseNet, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.fc3(x)
        x = self.sigmoid(x)
        return x

# %%
denseModel = SimpleDenseNet(
    input_dim=np.array([v for v in features_to_extract.values()]).sum(), hidden_dim=512
).to(device)

# %% [markdown]
# # Code declaring and computing all the metrics to measure

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    roc_auc_score,
    precision_recall_curve,
    auc
)


def compute_metrics(model, input_tensor, true_labels):
    with torch.no_grad():
        outputs = model(input_tensor)
        predicted_probs = torch.sigmoid(outputs).cpu().numpy()
        predicted = (outputs > 0.5).float().cpu().numpy()

        true_labels = true_labels.cpu().numpy()

        acc = accuracy_score(true_labels, predicted)
        precision = precision_score(true_labels, predicted)
        recall = recall_score(true_labels, predicted)
        f1 = f1_score(true_labels, predicted)

        precision_negative = precision_score(true_labels, predicted, pos_label=0)
        recall_negative = recall_score(true_labels, predicted, pos_label=0)
        f1_negative = f1_score(true_labels, predicted, pos_label=0)

        tn, fp, fn, tp = confusion_matrix(true_labels, predicted).ravel()
        roc_auc = roc_auc_score(true_labels, predicted_probs)

        P, R, thre = precision_recall_curve(true_labels, predicted, pos_label=1)
        pr_auc = auc(R, P)

        roc_auc_negative = roc_auc_score(
            true_labels, 1 - predicted_probs
        )  # If predicted_probs is the probability of the positive class
        P_neg, R_neg, _ = precision_recall_curve(true_labels, predicted, pos_label=0)
        pr_auc_negative = auc(R_neg, P_neg)

        return {
            "Accuracy": acc,
            "Precision": precision,
            "Recall": recall,
            "F1": f1,
            "TP": tp,
            "TN": tn,
            "FP": fp,
            "FN": fn,
            "ROC AUC": roc_auc,
            "PR AUC": pr_auc,
            "Precision-Negative": precision_negative,
            "Recall-Negative": recall_negative,
            "F1-Negative": f1_negative,
            "ROC AUC-Negative": roc_auc_negative,
            "PR AUC-Negative": pr_auc_negative,
        }

# %% [markdown]
# ## Code for training the Dense Model and getting the result of all metrics corresponding to the Testing Set.

# %%
def compute_accuracy(model, input_tensor, true_labels):
    with torch.no_grad():
        outputs = model(input_tensor)
        predicted = (outputs > 0.5).float()
        correct = (predicted == true_labels).float().sum()
        accuracy = correct / len(true_labels)
        return accuracy.item()


X_train_tensor = torch.tensor(X_train_features, dtype=torch.float32).to(device)
Y_train_tensor = torch.tensor(Y_train, dtype=torch.float32).view(-1, 1).to(device)

print(X_train_tensor.shape, Y_train_tensor.shape)

# Define loss and optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(denseModel.parameters(), lr=0.001)

bestValAcc = 0
# Training loop
num_epochs = 20000
for epoch in range(num_epochs):
    denseModel.train()
    optimizer.zero_grad()
    outputs = denseModel(X_train_tensor)
    loss = criterion(outputs, Y_train_tensor)
    loss.backward()
    optimizer.step()

    # Compute training accuracy
    train_accuracy = compute_accuracy(denseModel, X_train_tensor, Y_train_tensor)

    # Uncomment this if you want to see how the accuracy of testing improves during the training process.
    ##Compute testing accuracy
    # X_val_tensor = torch.tensor(X_val_features, dtype=torch.float32).to(device)
    # Y_val_tensor = torch.tensor(Y_val, dtype=torch.float32).view(-1, 1).to(device)

    # val_accuracy = compute_accuracy(denseModel, X_val_tensor, Y_val_tensor)

    # if bestValAcc < val_accuracy:
    #     bestValAcc = val_accuracy
    #     print(f'Saving model with best validation accuracy ...')
    #     torch.save(denseModel.state_dict(), 'llama-' + task + '-best-model')

    if (epoch + 1) % 10 == 0:
        print(
            f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Training Accuracy: {train_accuracy:.4f}"
        )  # , "Validation Accuracy": {val_accuracy:.4f}')
# Out:
# torch.Size([2000, 1]) torch.Size([2000, 1])
# Epoch [10/20000], Loss: 0.6759, Training Accuracy: 0.5595
# Epoch [20/20000], Loss: 0.6640, Training Accuracy: 0.5845
# Epoch [30/20000], Loss: 0.6538, Training Accuracy: 0.6010
# Epoch [40/20000], Loss: 0.6475, Training Accuracy: 0.6035
# Epoch [50/20000], Loss: 0.6443, Training Accuracy: 0.6015
# Epoch [60/20000], Loss: 0.6431, Training Accuracy: 0.6090
# Epoch [70/20000], Loss: 0.6426, Training Accuracy: 0.6030
# Epoch [80/20000], Loss: 0.6422, Training Accuracy: 0.6080
# Epoch [90/20000], Loss: 0.6419, Training Accuracy: 0.6060
# Epoch [100/20000], Loss: 0.6418, Training Accuracy: 0.6085
# Epoch [110/20000], Loss: 0.6417, Training Accuracy: 0.6110
# Epoch [120/20000], Loss: 0.6416, Training Accuracy: 0.6105
# Epoch [130/20000], Loss: 0.6415, Training Accuracy: 0.6100
# Epoch [140/20000], Loss: 0.6415, Training Accuracy: 0.6100
# Epoch [150/20000], Loss: 0.6415, Training Accuracy: 0.6100
# Epoch [160/20000], Loss: 0.6414, Training Accuracy: 0.6095
# Epoch [170/20000], Loss: 0.6414, Training Accuracy: 0.6095
# Epoch [180/20000], Loss: 0.6414, Training Accuracy: 0.6095
# Epoch [190/20000], Loss: 0.6414, Training Accuracy: 0.6095
# Epoch [200/20000], Loss: 0.6414, Training Accuracy: 0.6095
# Epoch [210/20000], Loss: 0.6413, Training Accuracy: 0.6095
# Epoch [220/20000], Loss: 0.6413, Training Accuracy: 0.6095
# Epoch [230/20000], Loss: 0.6413, Training Accuracy: 0.6095
# Epoch [240/20000], Loss: 0.6413, Training Accuracy: 0.6095
# Epoch [250/20000], Loss: 0.6413, Training Accuracy: 0.6095
# Epoch [260/20000], Loss: 0.6413, Training Accuracy: 0.6095
# Epoch [270/20000], Loss: 0.6413, Training Accuracy: 0.6095
# Epoch [280/20000], Loss: 0.6413, Training Accuracy: 0.6095
# Epoch [290/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [300/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [310/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [320/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [330/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [340/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [350/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [360/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [370/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [380/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [390/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [400/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [410/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [420/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [430/20000], Loss: 0.6411, Training Accuracy: 0.6095
# Epoch [440/20000], Loss: 0.6412, Training Accuracy: 0.6095
# Epoch [450/20000], Loss: 0.6411, Training Accuracy: 0.6080
# Epoch [460/20000], Loss: 0.6411, Training Accuracy: 0.6125
# Epoch [470/20000], Loss: 0.6411, Training Accuracy: 0.6080
# Epoch [480/20000], Loss: 0.6411, Training Accuracy: 0.6075
# Epoch [490/20000], Loss: 0.6411, Training Accuracy: 0.6080
# Epoch [500/20000], Loss: 0.6414, Training Accuracy: 0.6085
# Epoch [510/20000], Loss: 0.6412, Training Accuracy: 0.6110
# Epoch [520/20000], Loss: 0.6411, Training Accuracy: 0.6115
# Epoch [530/20000], Loss: 0.6411, Training Accuracy: 0.6100
# Epoch [540/20000], Loss: 0.6411, Training Accuracy: 0.6085
# Epoch [550/20000], Loss: 0.6411, Training Accuracy: 0.6105
# Epoch [560/20000], Loss: 0.6411, Training Accuracy: 0.6120
# Epoch [570/20000], Loss: 0.6411, Training Accuracy: 0.6110
# Epoch [580/20000], Loss: 0.6412, Training Accuracy: 0.6100
# Epoch [590/20000], Loss: 0.6412, Training Accuracy: 0.6085
# Epoch [600/20000], Loss: 0.6411, Training Accuracy: 0.6085
# Epoch [610/20000], Loss: 0.6411, Training Accuracy: 0.6120
# Epoch [620/20000], Loss: 0.6411, Training Accuracy: 0.6145
# Epoch [630/20000], Loss: 0.6411, Training Accuracy: 0.6085
# Epoch [640/20000], Loss: 0.6411, Training Accuracy: 0.6085
# Epoch [650/20000], Loss: 0.6411, Training Accuracy: 0.6085
# Epoch [660/20000], Loss: 0.6411, Training Accuracy: 0.6105
# Epoch [670/20000], Loss: 0.6411, Training Accuracy: 0.6135
# Epoch [680/20000], Loss: 0.6415, Training Accuracy: 0.6025
# Epoch [690/20000], Loss: 0.6413, Training Accuracy: 0.6080
# Epoch [700/20000], Loss: 0.6411, Training Accuracy: 0.6085
# Epoch [710/20000], Loss: 0.6410, Training Accuracy: 0.6090
# Epoch [720/20000], Loss: 0.6411, Training Accuracy: 0.6105
# Epoch [730/20000], Loss: 0.6410, Training Accuracy: 0.6105
# Epoch [740/20000], Loss: 0.6410, Training Accuracy: 0.6085
# Epoch [750/20000], Loss: 0.6410, Training Accuracy: 0.6105
# Epoch [760/20000], Loss: 0.6410, Training Accuracy: 0.6120
# Epoch [770/20000], Loss: 0.6411, Training Accuracy: 0.6130
# Epoch [780/20000], Loss: 0.6412, Training Accuracy: 0.6160
# Epoch [790/20000], Loss: 0.6410, Training Accuracy: 0.6085
# Epoch [800/20000], Loss: 0.6410, Training Accuracy: 0.6090
# Epoch [810/20000], Loss: 0.6410, Training Accuracy: 0.6100
# Epoch [820/20000], Loss: 0.6410, Training Accuracy: 0.6090
# Epoch [830/20000], Loss: 0.6410, Training Accuracy: 0.6090
# Epoch [840/20000], Loss: 0.6410, Training Accuracy: 0.6090
# Epoch [850/20000], Loss: 0.6415, Training Accuracy: 0.6075
# Epoch [860/20000], Loss: 0.6412, Training Accuracy: 0.6110
# Epoch [870/20000], Loss: 0.6410, Training Accuracy: 0.6090
# Epoch [880/20000], Loss: 0.6410, Training Accuracy: 0.6080
# Epoch [890/20000], Loss: 0.6410, Training Accuracy: 0.6085
# Epoch [900/20000], Loss: 0.6410, Training Accuracy: 0.6140
# Epoch [910/20000], Loss: 0.6410, Training Accuracy: 0.6090
# Epoch [920/20000], Loss: 0.6410, Training Accuracy: 0.6080
# Epoch [930/20000], Loss: 0.6410, Training Accuracy: 0.6080
# Epoch [940/20000], Loss: 0.6413, Training Accuracy: 0.6090
# Epoch [950/20000], Loss: 0.6411, Training Accuracy: 0.6100
# Epoch [960/20000], Loss: 0.6410, Training Accuracy: 0.6095
# Epoch [970/20000], Loss: 0.6410, Training Accuracy: 0.6110
# Epoch [980/20000], Loss: 0.6410, Training Accuracy: 0.6095
# Epoch [990/20000], Loss: 0.6410, Training Accuracy: 0.6085
# Epoch [1000/20000], Loss: 0.6413, Training Accuracy: 0.6085
# Epoch [1010/20000], Loss: 0.6411, Training Accuracy: 0.6160
# Epoch [1020/20000], Loss: 0.6410, Training Accuracy: 0.6090
# Epoch [1030/20000], Loss: 0.6410, Training Accuracy: 0.6100
# Epoch [1040/20000], Loss: 0.6409, Training Accuracy: 0.6130
# Epoch [1050/20000], Loss: 0.6409, Training Accuracy: 0.6130
# Epoch [1060/20000], Loss: 0.6411, Training Accuracy: 0.6110
# Epoch [1070/20000], Loss: 0.6410, Training Accuracy: 0.6085
# Epoch [1080/20000], Loss: 0.6409, Training Accuracy: 0.6085
# Epoch [1090/20000], Loss: 0.6410, Training Accuracy: 0.6095
# Epoch [1100/20000], Loss: 0.6409, Training Accuracy: 0.6105
# Epoch [1110/20000], Loss: 0.6409, Training Accuracy: 0.6100
# Epoch [1120/20000], Loss: 0.6409, Training Accuracy: 0.6095
# Epoch [1130/20000], Loss: 0.6409, Training Accuracy: 0.6105
# Epoch [1140/20000], Loss: 0.6409, Training Accuracy: 0.6115
# Epoch [1150/20000], Loss: 0.6409, Training Accuracy: 0.6115
# Epoch [1160/20000], Loss: 0.6409, Training Accuracy: 0.6110
# Epoch [1170/20000], Loss: 0.6409, Training Accuracy: 0.6100
# Epoch [1180/20000], Loss: 0.6411, Training Accuracy: 0.6085
# Epoch [1190/20000], Loss: 0.6410, Training Accuracy: 0.6095
# Epoch [1200/20000], Loss: 0.6409, Training Accuracy: 0.6095
# Epoch [1210/20000], Loss: 0.6409, Training Accuracy: 0.6095
# Epoch [1220/20000], Loss: 0.6409, Training Accuracy: 0.6100
# Epoch [1230/20000], Loss: 0.6409, Training Accuracy: 0.6100
# Epoch [1240/20000], Loss: 0.6409, Training Accuracy: 0.6115
# Epoch [1250/20000], Loss: 0.6409, Training Accuracy: 0.6100
# Epoch [1260/20000], Loss: 0.6424, Training Accuracy: 0.6100
# Epoch [1270/20000], Loss: 0.6411, Training Accuracy: 0.6080
# Epoch [1280/20000], Loss: 0.6409, Training Accuracy: 0.6120
# Epoch [1290/20000], Loss: 0.6409, Training Accuracy: 0.6115
# Epoch [1300/20000], Loss: 0.6409, Training Accuracy: 0.6100
# Epoch [1310/20000], Loss: 0.6409, Training Accuracy: 0.6095
# Epoch [1320/20000], Loss: 0.6409, Training Accuracy: 0.6095
# Epoch [1330/20000], Loss: 0.6409, Training Accuracy: 0.6110
# Epoch [1340/20000], Loss: 0.6409, Training Accuracy: 0.6105
# Epoch [1350/20000], Loss: 0.6409, Training Accuracy: 0.6110
# Epoch [1360/20000], Loss: 0.6408, Training Accuracy: 0.6120
# Epoch [1370/20000], Loss: 0.6408, Training Accuracy: 0.6115
# Epoch [1380/20000], Loss: 0.6408, Training Accuracy: 0.6125
# Epoch [1390/20000], Loss: 0.6408, Training Accuracy: 0.6100
# Epoch [1400/20000], Loss: 0.6408, Training Accuracy: 0.6090
# Epoch [1410/20000], Loss: 0.6409, Training Accuracy: 0.6110
# Epoch [1420/20000], Loss: 0.6410, Training Accuracy: 0.6090
# Epoch [1430/20000], Loss: 0.6408, Training Accuracy: 0.6100
# Epoch [1440/20000], Loss: 0.6409, Training Accuracy: 0.6145
# Epoch [1450/20000], Loss: 0.6408, Training Accuracy: 0.6095
# Epoch [1460/20000], Loss: 0.6408, Training Accuracy: 0.6100
# Epoch [1470/20000], Loss: 0.6408, Training Accuracy: 0.6110
# Epoch [1480/20000], Loss: 0.6408, Training Accuracy: 0.6095
# Epoch [1490/20000], Loss: 0.6415, Training Accuracy: 0.6090
# Epoch [1500/20000], Loss: 0.6410, Training Accuracy: 0.6165
# Epoch [1510/20000], Loss: 0.6408, Training Accuracy: 0.6130
# Epoch [1520/20000], Loss: 0.6408, Training Accuracy: 0.6095
# Epoch [1530/20000], Loss: 0.6408, Training Accuracy: 0.6115
# Epoch [1540/20000], Loss: 0.6408, Training Accuracy: 0.6115
# Epoch [1550/20000], Loss: 0.6413, Training Accuracy: 0.6115
# Epoch [1560/20000], Loss: 0.6408, Training Accuracy: 0.6125
# Epoch [1570/20000], Loss: 0.6409, Training Accuracy: 0.6090
# Epoch [1580/20000], Loss: 0.6408, Training Accuracy: 0.6105
# Epoch [1590/20000], Loss: 0.6408, Training Accuracy: 0.6140
# Epoch [1600/20000], Loss: 0.6408, Training Accuracy: 0.6125
# Epoch [1610/20000], Loss: 0.6408, Training Accuracy: 0.6095
# Epoch [1620/20000], Loss: 0.6408, Training Accuracy: 0.6090
# Epoch [1630/20000], Loss: 0.6412, Training Accuracy: 0.6110
# Epoch [1640/20000], Loss: 0.6409, Training Accuracy: 0.6115
# Epoch [1650/20000], Loss: 0.6408, Training Accuracy: 0.6120
# Epoch [1660/20000], Loss: 0.6407, Training Accuracy: 0.6110
# Epoch [1670/20000], Loss: 0.6408, Training Accuracy: 0.6095
# Epoch [1680/20000], Loss: 0.6407, Training Accuracy: 0.6095
# Epoch [1690/20000], Loss: 0.6409, Training Accuracy: 0.6090
# Epoch [1700/20000], Loss: 0.6409, Training Accuracy: 0.6100
# Epoch [1710/20000], Loss: 0.6409, Training Accuracy: 0.6095
# Epoch [1720/20000], Loss: 0.6407, Training Accuracy: 0.6095
# Epoch [1730/20000], Loss: 0.6407, Training Accuracy: 0.6120
# Epoch [1740/20000], Loss: 0.6407, Training Accuracy: 0.6150
# Epoch [1750/20000], Loss: 0.6407, Training Accuracy: 0.6115
# Epoch [1760/20000], Loss: 0.6407, Training Accuracy: 0.6120
# Epoch [1770/20000], Loss: 0.6407, Training Accuracy: 0.6125
# Epoch [1780/20000], Loss: 0.6407, Training Accuracy: 0.6095
# Epoch [1790/20000], Loss: 0.6417, Training Accuracy: 0.6080
# Epoch [1800/20000], Loss: 0.6409, Training Accuracy: 0.6060
# Epoch [1810/20000], Loss: 0.6409, Training Accuracy: 0.6160
# Epoch [1820/20000], Loss: 0.6407, Training Accuracy: 0.6130
# Epoch [1830/20000], Loss: 0.6407, Training Accuracy: 0.6090
# Epoch [1840/20000], Loss: 0.6407, Training Accuracy: 0.6105
# Epoch [1850/20000], Loss: 0.6407, Training Accuracy: 0.6115
# Epoch [1860/20000], Loss: 0.6407, Training Accuracy: 0.6130
# Epoch [1870/20000], Loss: 0.6407, Training Accuracy: 0.6125
# Epoch [1880/20000], Loss: 0.6407, Training Accuracy: 0.6130
# Epoch [1890/20000], Loss: 0.6407, Training Accuracy: 0.6125
# Epoch [1900/20000], Loss: 0.6407, Training Accuracy: 0.6120
# Epoch [1910/20000], Loss: 0.6407, Training Accuracy: 0.6095
# Epoch [1920/20000], Loss: 0.6409, Training Accuracy: 0.6090
# Epoch [1930/20000], Loss: 0.6407, Training Accuracy: 0.6135
# Epoch [1940/20000], Loss: 0.6406, Training Accuracy: 0.6095
# Epoch [1950/20000], Loss: 0.6407, Training Accuracy: 0.6130
# Epoch [1960/20000], Loss: 0.6406, Training Accuracy: 0.6115
# Epoch [1970/20000], Loss: 0.6406, Training Accuracy: 0.6120
# Epoch [1980/20000], Loss: 0.6407, Training Accuracy: 0.6095
# Epoch [1990/20000], Loss: 0.6411, Training Accuracy: 0.6110
# Epoch [2000/20000], Loss: 0.6408, Training Accuracy: 0.6095
# Epoch [2010/20000], Loss: 0.6407, Training Accuracy: 0.6090
# Epoch [2020/20000], Loss: 0.6406, Training Accuracy: 0.6120
# Epoch [2030/20000], Loss: 0.6406, Training Accuracy: 0.6095
# Epoch [2040/20000], Loss: 0.6407, Training Accuracy: 0.6085
# Epoch [2050/20000], Loss: 0.6407, Training Accuracy: 0.6095
# Epoch [2060/20000], Loss: 0.6408, Training Accuracy: 0.6100
# Epoch [2070/20000], Loss: 0.6406, Training Accuracy: 0.6125
# Epoch [2080/20000], Loss: 0.6406, Training Accuracy: 0.6110
# Epoch [2090/20000], Loss: 0.6443, Training Accuracy: 0.5990
# Epoch [2100/20000], Loss: 0.6413, Training Accuracy: 0.6120
# Epoch [2110/20000], Loss: 0.6409, Training Accuracy: 0.6090
# Epoch [2120/20000], Loss: 0.6406, Training Accuracy: 0.6090
# Epoch [2130/20000], Loss: 0.6406, Training Accuracy: 0.6110
# Epoch [2140/20000], Loss: 0.6406, Training Accuracy: 0.6135
# Epoch [2150/20000], Loss: 0.6406, Training Accuracy: 0.6110
# Epoch [2160/20000], Loss: 0.6406, Training Accuracy: 0.6110
# Epoch [2170/20000], Loss: 0.6406, Training Accuracy: 0.6130
# Epoch [2180/20000], Loss: 0.6406, Training Accuracy: 0.6125
# Epoch [2190/20000], Loss: 0.6406, Training Accuracy: 0.6125
# Epoch [2200/20000], Loss: 0.6406, Training Accuracy: 0.6120
# Epoch [2210/20000], Loss: 0.6406, Training Accuracy: 0.6130
# Epoch [2220/20000], Loss: 0.6405, Training Accuracy: 0.6135
# Epoch [2230/20000], Loss: 0.6405, Training Accuracy: 0.6125
# Epoch [2240/20000], Loss: 0.6405, Training Accuracy: 0.6135
# Epoch [2250/20000], Loss: 0.6405, Training Accuracy: 0.6130
# Epoch [2260/20000], Loss: 0.6405, Training Accuracy: 0.6150
# Epoch [2270/20000], Loss: 0.6405, Training Accuracy: 0.6135
# Epoch [2280/20000], Loss: 0.6405, Training Accuracy: 0.6135
# Epoch [2290/20000], Loss: 0.6405, Training Accuracy: 0.6125
# Epoch [2300/20000], Loss: 0.6405, Training Accuracy: 0.6140
# Epoch [2310/20000], Loss: 0.6405, Training Accuracy: 0.6155
# Epoch [2320/20000], Loss: 0.6405, Training Accuracy: 0.6120
# Epoch [2330/20000], Loss: 0.6405, Training Accuracy: 0.6115
# Epoch [2340/20000], Loss: 0.6405, Training Accuracy: 0.6060
# Epoch [2350/20000], Loss: 0.6406, Training Accuracy: 0.6160
# Epoch [2360/20000], Loss: 0.6406, Training Accuracy: 0.6085
# Epoch [2370/20000], Loss: 0.6405, Training Accuracy: 0.6095
# Epoch [2380/20000], Loss: 0.6406, Training Accuracy: 0.6100
# Epoch [2390/20000], Loss: 0.6404, Training Accuracy: 0.6160
# Epoch [2400/20000], Loss: 0.6405, Training Accuracy: 0.6145
# Epoch [2410/20000], Loss: 0.6406, Training Accuracy: 0.6160
# Epoch [2420/20000], Loss: 0.6404, Training Accuracy: 0.6120
# Epoch [2430/20000], Loss: 0.6405, Training Accuracy: 0.6090
# Epoch [2440/20000], Loss: 0.6404, Training Accuracy: 0.6105
# Epoch [2450/20000], Loss: 0.6406, Training Accuracy: 0.6100
# Epoch [2460/20000], Loss: 0.6405, Training Accuracy: 0.6125
# Epoch [2470/20000], Loss: 0.6405, Training Accuracy: 0.6140
# Epoch [2480/20000], Loss: 0.6404, Training Accuracy: 0.6105
# Epoch [2490/20000], Loss: 0.6404, Training Accuracy: 0.6105
# Epoch [2500/20000], Loss: 0.6406, Training Accuracy: 0.6110
# Epoch [2510/20000], Loss: 0.6404, Training Accuracy: 0.6125
# Epoch [2520/20000], Loss: 0.6404, Training Accuracy: 0.6110
# Epoch [2530/20000], Loss: 0.6404, Training Accuracy: 0.6120
# Epoch [2540/20000], Loss: 0.6405, Training Accuracy: 0.6100
# Epoch [2550/20000], Loss: 0.6404, Training Accuracy: 0.6105
# Epoch [2560/20000], Loss: 0.6403, Training Accuracy: 0.6105
# Epoch [2570/20000], Loss: 0.6404, Training Accuracy: 0.6085
# Epoch [2580/20000], Loss: 0.6410, Training Accuracy: 0.6110
# Epoch [2590/20000], Loss: 0.6403, Training Accuracy: 0.6125
# Epoch [2600/20000], Loss: 0.6404, Training Accuracy: 0.6155
# Epoch [2610/20000], Loss: 0.6403, Training Accuracy: 0.6120
# Epoch [2620/20000], Loss: 0.6403, Training Accuracy: 0.6120
# Epoch [2630/20000], Loss: 0.6403, Training Accuracy: 0.6130
# Epoch [2640/20000], Loss: 0.6403, Training Accuracy: 0.6125
# Epoch [2650/20000], Loss: 0.6403, Training Accuracy: 0.6135
# Epoch [2660/20000], Loss: 0.6405, Training Accuracy: 0.6100
# Epoch [2670/20000], Loss: 0.6403, Training Accuracy: 0.6135
# Epoch [2680/20000], Loss: 0.6407, Training Accuracy: 0.6105
# Epoch [2690/20000], Loss: 0.6405, Training Accuracy: 0.6100
# Epoch [2700/20000], Loss: 0.6403, Training Accuracy: 0.6115
# Epoch [2710/20000], Loss: 0.6403, Training Accuracy: 0.6130
# Epoch [2720/20000], Loss: 0.6403, Training Accuracy: 0.6130
# Epoch [2730/20000], Loss: 0.6403, Training Accuracy: 0.6145
# Epoch [2740/20000], Loss: 0.6403, Training Accuracy: 0.6125
# Epoch [2750/20000], Loss: 0.6404, Training Accuracy: 0.6110
# Epoch [2760/20000], Loss: 0.6402, Training Accuracy: 0.6120
# Epoch [2770/20000], Loss: 0.6404, Training Accuracy: 0.6100
# Epoch [2780/20000], Loss: 0.6402, Training Accuracy: 0.6120
# Epoch [2790/20000], Loss: 0.6403, Training Accuracy: 0.6130
# Epoch [2800/20000], Loss: 0.6403, Training Accuracy: 0.6135
# Epoch [2810/20000], Loss: 0.6403, Training Accuracy: 0.6100
# Epoch [2820/20000], Loss: 0.6402, Training Accuracy: 0.6110
# Epoch [2830/20000], Loss: 0.6402, Training Accuracy: 0.6120
# Epoch [2840/20000], Loss: 0.6408, Training Accuracy: 0.6100
# Epoch [2850/20000], Loss: 0.6405, Training Accuracy: 0.6105
# Epoch [2860/20000], Loss: 0.6402, Training Accuracy: 0.6120
# Epoch [2870/20000], Loss: 0.6402, Training Accuracy: 0.6115
# Epoch [2880/20000], Loss: 0.6402, Training Accuracy: 0.6115
# Epoch [2890/20000], Loss: 0.6402, Training Accuracy: 0.6145
# Epoch [2900/20000], Loss: 0.6402, Training Accuracy: 0.6125
# Epoch [2910/20000], Loss: 0.6402, Training Accuracy: 0.6100
# Epoch [2920/20000], Loss: 0.6403, Training Accuracy: 0.6100
# Epoch [2930/20000], Loss: 0.6401, Training Accuracy: 0.6125
# Epoch [2940/20000], Loss: 0.6404, Training Accuracy: 0.6125
# Epoch [2950/20000], Loss: 0.6401, Training Accuracy: 0.6100
# Epoch [2960/20000], Loss: 0.6402, Training Accuracy: 0.6110
# Epoch [2970/20000], Loss: 0.6401, Training Accuracy: 0.6110
# Epoch [2980/20000], Loss: 0.6401, Training Accuracy: 0.6120
# Epoch [2990/20000], Loss: 0.6401, Training Accuracy: 0.6135
# Epoch [3000/20000], Loss: 0.6401, Training Accuracy: 0.6120
# Epoch [3010/20000], Loss: 0.6401, Training Accuracy: 0.6165
# Epoch [3020/20000], Loss: 0.6401, Training Accuracy: 0.6115
# Epoch [3030/20000], Loss: 0.6401, Training Accuracy: 0.6110
# Epoch [3040/20000], Loss: 0.6400, Training Accuracy: 0.6110
# Epoch [3050/20000], Loss: 0.6402, Training Accuracy: 0.6105
# Epoch [3060/20000], Loss: 0.6400, Training Accuracy: 0.6150
# Epoch [3070/20000], Loss: 0.6400, Training Accuracy: 0.6125
# Epoch [3080/20000], Loss: 0.6400, Training Accuracy: 0.6140
# Epoch [3090/20000], Loss: 0.6400, Training Accuracy: 0.6110
# Epoch [3100/20000], Loss: 0.6401, Training Accuracy: 0.6100
# Epoch [3110/20000], Loss: 0.6400, Training Accuracy: 0.6130
# Epoch [3120/20000], Loss: 0.6402, Training Accuracy: 0.6105
# Epoch [3130/20000], Loss: 0.6400, Training Accuracy: 0.6105
# Epoch [3140/20000], Loss: 0.6408, Training Accuracy: 0.6095
# Epoch [3150/20000], Loss: 0.6400, Training Accuracy: 0.6165
# Epoch [3160/20000], Loss: 0.6401, Training Accuracy: 0.6150
# Epoch [3170/20000], Loss: 0.6400, Training Accuracy: 0.6140
# Epoch [3180/20000], Loss: 0.6400, Training Accuracy: 0.6135
# Epoch [3190/20000], Loss: 0.6400, Training Accuracy: 0.6145
# Epoch [3200/20000], Loss: 0.6400, Training Accuracy: 0.6130
# Epoch [3210/20000], Loss: 0.6400, Training Accuracy: 0.6125
# Epoch [3220/20000], Loss: 0.6400, Training Accuracy: 0.6085
# Epoch [3230/20000], Loss: 0.6402, Training Accuracy: 0.6085
# Epoch [3240/20000], Loss: 0.6399, Training Accuracy: 0.6150
# Epoch [3250/20000], Loss: 0.6400, Training Accuracy: 0.6110
# Epoch [3260/20000], Loss: 0.6400, Training Accuracy: 0.6140
# Epoch [3270/20000], Loss: 0.6400, Training Accuracy: 0.6110
# Epoch [3280/20000], Loss: 0.6399, Training Accuracy: 0.6125
# Epoch [3290/20000], Loss: 0.6402, Training Accuracy: 0.6110
# Epoch [3300/20000], Loss: 0.6399, Training Accuracy: 0.6105
# Epoch [3310/20000], Loss: 0.6400, Training Accuracy: 0.6125
# Epoch [3320/20000], Loss: 0.6399, Training Accuracy: 0.6130
# Epoch [3330/20000], Loss: 0.6399, Training Accuracy: 0.6120
# Epoch [3340/20000], Loss: 0.6399, Training Accuracy: 0.6130
# Epoch [3350/20000], Loss: 0.6399, Training Accuracy: 0.6120
# Epoch [3360/20000], Loss: 0.6398, Training Accuracy: 0.6145
# Epoch [3370/20000], Loss: 0.6399, Training Accuracy: 0.6110
# Epoch [3380/20000], Loss: 0.6402, Training Accuracy: 0.6110
# Epoch [3390/20000], Loss: 0.6398, Training Accuracy: 0.6155
# Epoch [3400/20000], Loss: 0.6399, Training Accuracy: 0.6165
# Epoch [3410/20000], Loss: 0.6399, Training Accuracy: 0.6125
# Epoch [3420/20000], Loss: 0.6398, Training Accuracy: 0.6135
# Epoch [3430/20000], Loss: 0.6398, Training Accuracy: 0.6150
# Epoch [3440/20000], Loss: 0.6398, Training Accuracy: 0.6125
# Epoch [3450/20000], Loss: 0.6398, Training Accuracy: 0.6120
# Epoch [3460/20000], Loss: 0.6400, Training Accuracy: 0.6145
# Epoch [3470/20000], Loss: 0.6398, Training Accuracy: 0.6135
# Epoch [3480/20000], Loss: 0.6400, Training Accuracy: 0.6115
# Epoch [3490/20000], Loss: 0.6398, Training Accuracy: 0.6120
# Epoch [3500/20000], Loss: 0.6398, Training Accuracy: 0.6140
# Epoch [3510/20000], Loss: 0.6398, Training Accuracy: 0.6095
# Epoch [3520/20000], Loss: 0.6397, Training Accuracy: 0.6155
# Epoch [3530/20000], Loss: 0.6397, Training Accuracy: 0.6125
# Epoch [3540/20000], Loss: 0.6397, Training Accuracy: 0.6115
# Epoch [3550/20000], Loss: 0.6397, Training Accuracy: 0.6130
# Epoch [3560/20000], Loss: 0.6400, Training Accuracy: 0.6100
# Epoch [3570/20000], Loss: 0.6397, Training Accuracy: 0.6105
# Epoch [3580/20000], Loss: 0.6399, Training Accuracy: 0.6120
# Epoch [3590/20000], Loss: 0.6397, Training Accuracy: 0.6155
# Epoch [3600/20000], Loss: 0.6397, Training Accuracy: 0.6155
# Epoch [3610/20000], Loss: 0.6397, Training Accuracy: 0.6170
# Epoch [3620/20000], Loss: 0.6397, Training Accuracy: 0.6155
# Epoch [3630/20000], Loss: 0.6397, Training Accuracy: 0.6165
# Epoch [3640/20000], Loss: 0.6397, Training Accuracy: 0.6125
# Epoch [3650/20000], Loss: 0.6397, Training Accuracy: 0.6130
# Epoch [3660/20000], Loss: 0.6399, Training Accuracy: 0.6115
# Epoch [3670/20000], Loss: 0.6397, Training Accuracy: 0.6140
# Epoch [3680/20000], Loss: 0.6398, Training Accuracy: 0.6105
# Epoch [3690/20000], Loss: 0.6397, Training Accuracy: 0.6130
# Epoch [3700/20000], Loss: 0.6396, Training Accuracy: 0.6130
# Epoch [3710/20000], Loss: 0.6396, Training Accuracy: 0.6140
# Epoch [3720/20000], Loss: 0.6411, Training Accuracy: 0.6130
# Epoch [3730/20000], Loss: 0.6398, Training Accuracy: 0.6150
# Epoch [3740/20000], Loss: 0.6398, Training Accuracy: 0.6115
# Epoch [3750/20000], Loss: 0.6397, Training Accuracy: 0.6115
# Epoch [3760/20000], Loss: 0.6396, Training Accuracy: 0.6110
# Epoch [3770/20000], Loss: 0.6396, Training Accuracy: 0.6165
# Epoch [3780/20000], Loss: 0.6396, Training Accuracy: 0.6125
# Epoch [3790/20000], Loss: 0.6396, Training Accuracy: 0.6115
# Epoch [3800/20000], Loss: 0.6396, Training Accuracy: 0.6155
# Epoch [3810/20000], Loss: 0.6396, Training Accuracy: 0.6135
# Epoch [3820/20000], Loss: 0.6395, Training Accuracy: 0.6135
# Epoch [3830/20000], Loss: 0.6403, Training Accuracy: 0.6080
# Epoch [3840/20000], Loss: 0.6401, Training Accuracy: 0.6140
# Epoch [3850/20000], Loss: 0.6396, Training Accuracy: 0.6130
# Epoch [3860/20000], Loss: 0.6396, Training Accuracy: 0.6150
# Epoch [3870/20000], Loss: 0.6395, Training Accuracy: 0.6150
# Epoch [3880/20000], Loss: 0.6395, Training Accuracy: 0.6145
# Epoch [3890/20000], Loss: 0.6395, Training Accuracy: 0.6140
# Epoch [3900/20000], Loss: 0.6395, Training Accuracy: 0.6140
# Epoch [3910/20000], Loss: 0.6395, Training Accuracy: 0.6120
# Epoch [3920/20000], Loss: 0.6397, Training Accuracy: 0.6120
# Epoch [3930/20000], Loss: 0.6396, Training Accuracy: 0.6120
# Epoch [3940/20000], Loss: 0.6395, Training Accuracy: 0.6155
# Epoch [3950/20000], Loss: 0.6395, Training Accuracy: 0.6110
# Epoch [3960/20000], Loss: 0.6406, Training Accuracy: 0.6140
# Epoch [3970/20000], Loss: 0.6396, Training Accuracy: 0.6125
# Epoch [3980/20000], Loss: 0.6396, Training Accuracy: 0.6110
# Epoch [3990/20000], Loss: 0.6395, Training Accuracy: 0.6130
# Epoch [4000/20000], Loss: 0.6395, Training Accuracy: 0.6150
# Epoch [4010/20000], Loss: 0.6395, Training Accuracy: 0.6165
# Epoch [4020/20000], Loss: 0.6394, Training Accuracy: 0.6120
# Epoch [4030/20000], Loss: 0.6394, Training Accuracy: 0.6120
# Epoch [4040/20000], Loss: 0.6394, Training Accuracy: 0.6115
# Epoch [4050/20000], Loss: 0.6399, Training Accuracy: 0.6155
# Epoch [4060/20000], Loss: 0.6396, Training Accuracy: 0.6110
# Epoch [4070/20000], Loss: 0.6395, Training Accuracy: 0.6120
# Epoch [4080/20000], Loss: 0.6395, Training Accuracy: 0.6125
# Epoch [4090/20000], Loss: 0.6394, Training Accuracy: 0.6180
# Epoch [4100/20000], Loss: 0.6395, Training Accuracy: 0.6125
# Epoch [4110/20000], Loss: 0.6394, Training Accuracy: 0.6125
# Epoch [4120/20000], Loss: 0.6396, Training Accuracy: 0.6135
# Epoch [4130/20000], Loss: 0.6396, Training Accuracy: 0.6150
# Epoch [4140/20000], Loss: 0.6394, Training Accuracy: 0.6145
# Epoch [4150/20000], Loss: 0.6394, Training Accuracy: 0.6150
# Epoch [4160/20000], Loss: 0.6394, Training Accuracy: 0.6165
# Epoch [4170/20000], Loss: 0.6394, Training Accuracy: 0.6125
# Epoch [4180/20000], Loss: 0.6395, Training Accuracy: 0.6130
# Epoch [4190/20000], Loss: 0.6395, Training Accuracy: 0.6120
# Epoch [4200/20000], Loss: 0.6394, Training Accuracy: 0.6110
# Epoch [4210/20000], Loss: 0.6395, Training Accuracy: 0.6135
# Epoch [4220/20000], Loss: 0.6393, Training Accuracy: 0.6130
# Epoch [4230/20000], Loss: 0.6393, Training Accuracy: 0.6115
# Epoch [4240/20000], Loss: 0.6393, Training Accuracy: 0.6115
# Epoch [4250/20000], Loss: 0.6419, Training Accuracy: 0.6005
# Epoch [4260/20000], Loss: 0.6395, Training Accuracy: 0.6155
# Epoch [4270/20000], Loss: 0.6395, Training Accuracy: 0.6130
# Epoch [4280/20000], Loss: 0.6394, Training Accuracy: 0.6155
# Epoch [4290/20000], Loss: 0.6393, Training Accuracy: 0.6110
# Epoch [4300/20000], Loss: 0.6393, Training Accuracy: 0.6135
# Epoch [4310/20000], Loss: 0.6393, Training Accuracy: 0.6125
# Epoch [4320/20000], Loss: 0.6393, Training Accuracy: 0.6115
# Epoch [4330/20000], Loss: 0.6393, Training Accuracy: 0.6120
# Epoch [4340/20000], Loss: 0.6393, Training Accuracy: 0.6135
# Epoch [4350/20000], Loss: 0.6393, Training Accuracy: 0.6140
# Epoch [4360/20000], Loss: 0.6392, Training Accuracy: 0.6135
# Epoch [4370/20000], Loss: 0.6393, Training Accuracy: 0.6140
# Epoch [4380/20000], Loss: 0.6392, Training Accuracy: 0.6155
# Epoch [4390/20000], Loss: 0.6393, Training Accuracy: 0.6150
# Epoch [4400/20000], Loss: 0.6396, Training Accuracy: 0.6170
# Epoch [4410/20000], Loss: 0.6392, Training Accuracy: 0.6160
# Epoch [4420/20000], Loss: 0.6394, Training Accuracy: 0.6125
# Epoch [4430/20000], Loss: 0.6392, Training Accuracy: 0.6135
# Epoch [4440/20000], Loss: 0.6394, Training Accuracy: 0.6130
# Epoch [4450/20000], Loss: 0.6396, Training Accuracy: 0.6130
# Epoch [4460/20000], Loss: 0.6395, Training Accuracy: 0.6140
# Epoch [4470/20000], Loss: 0.6394, Training Accuracy: 0.6125
# Epoch [4480/20000], Loss: 0.6393, Training Accuracy: 0.6195
# Epoch [4490/20000], Loss: 0.6392, Training Accuracy: 0.6180
# Epoch [4500/20000], Loss: 0.6393, Training Accuracy: 0.6125
# Epoch [4510/20000], Loss: 0.6394, Training Accuracy: 0.6125
# Epoch [4520/20000], Loss: 0.6392, Training Accuracy: 0.6150
# Epoch [4530/20000], Loss: 0.6394, Training Accuracy: 0.6120
# Epoch [4540/20000], Loss: 0.6394, Training Accuracy: 0.6150
# Epoch [4550/20000], Loss: 0.6393, Training Accuracy: 0.6135
# Epoch [4560/20000], Loss: 0.6392, Training Accuracy: 0.6155
# Epoch [4570/20000], Loss: 0.6392, Training Accuracy: 0.6160
# Epoch [4580/20000], Loss: 0.6392, Training Accuracy: 0.6125
# Epoch [4590/20000], Loss: 0.6393, Training Accuracy: 0.6130
# Epoch [4600/20000], Loss: 0.6398, Training Accuracy: 0.6155
# Epoch [4610/20000], Loss: 0.6394, Training Accuracy: 0.6125
# Epoch [4620/20000], Loss: 0.6392, Training Accuracy: 0.6155
# Epoch [4630/20000], Loss: 0.6392, Training Accuracy: 0.6140
# Epoch [4640/20000], Loss: 0.6392, Training Accuracy: 0.6125
# Epoch [4650/20000], Loss: 0.6391, Training Accuracy: 0.6155
# Epoch [4660/20000], Loss: 0.6391, Training Accuracy: 0.6145
# Epoch [4670/20000], Loss: 0.6392, Training Accuracy: 0.6130
# Epoch [4680/20000], Loss: 0.6400, Training Accuracy: 0.6165
# Epoch [4690/20000], Loss: 0.6395, Training Accuracy: 0.6145
# Epoch [4700/20000], Loss: 0.6393, Training Accuracy: 0.6125
# Epoch [4710/20000], Loss: 0.6391, Training Accuracy: 0.6125
# Epoch [4720/20000], Loss: 0.6391, Training Accuracy: 0.6180
# Epoch [4730/20000], Loss: 0.6391, Training Accuracy: 0.6145
# Epoch [4740/20000], Loss: 0.6391, Training Accuracy: 0.6135
# Epoch [4750/20000], Loss: 0.6392, Training Accuracy: 0.6125
# Epoch [4760/20000], Loss: 0.6393, Training Accuracy: 0.6125
# Epoch [4770/20000], Loss: 0.6391, Training Accuracy: 0.6165
# Epoch [4780/20000], Loss: 0.6391, Training Accuracy: 0.6130
# Epoch [4790/20000], Loss: 0.6398, Training Accuracy: 0.6155
# Epoch [4800/20000], Loss: 0.6393, Training Accuracy: 0.6155
# Epoch [4810/20000], Loss: 0.6391, Training Accuracy: 0.6120
# Epoch [4820/20000], Loss: 0.6391, Training Accuracy: 0.6145
# Epoch [4830/20000], Loss: 0.6390, Training Accuracy: 0.6160
# Epoch [4840/20000], Loss: 0.6391, Training Accuracy: 0.6120
# Epoch [4850/20000], Loss: 0.6392, Training Accuracy: 0.6120
# Epoch [4860/20000], Loss: 0.6390, Training Accuracy: 0.6130
# Epoch [4870/20000], Loss: 0.6391, Training Accuracy: 0.6130
# Epoch [4880/20000], Loss: 0.6398, Training Accuracy: 0.6135
# Epoch [4890/20000], Loss: 0.6391, Training Accuracy: 0.6135
# Epoch [4900/20000], Loss: 0.6390, Training Accuracy: 0.6195
# Epoch [4910/20000], Loss: 0.6390, Training Accuracy: 0.6130
# Epoch [4920/20000], Loss: 0.6390, Training Accuracy: 0.6155
# Epoch [4930/20000], Loss: 0.6390, Training Accuracy: 0.6155
# Epoch [4940/20000], Loss: 0.6390, Training Accuracy: 0.6120
# Epoch [4950/20000], Loss: 0.6390, Training Accuracy: 0.6135
# Epoch [4960/20000], Loss: 0.6393, Training Accuracy: 0.6140
# Epoch [4970/20000], Loss: 0.6391, Training Accuracy: 0.6115
# Epoch [4980/20000], Loss: 0.6390, Training Accuracy: 0.6125
# Epoch [4990/20000], Loss: 0.6390, Training Accuracy: 0.6150
# Epoch [5000/20000], Loss: 0.6390, Training Accuracy: 0.6135
# Epoch [5010/20000], Loss: 0.6390, Training Accuracy: 0.6130
# Epoch [5020/20000], Loss: 0.6389, Training Accuracy: 0.6130
# Epoch [5030/20000], Loss: 0.6391, Training Accuracy: 0.6185
# Epoch [5040/20000], Loss: 0.6392, Training Accuracy: 0.6160
# Epoch [5050/20000], Loss: 0.6392, Training Accuracy: 0.6135
# Epoch [5060/20000], Loss: 0.6389, Training Accuracy: 0.6130
# Epoch [5070/20000], Loss: 0.6391, Training Accuracy: 0.6175
# Epoch [5080/20000], Loss: 0.6389, Training Accuracy: 0.6120
# Epoch [5090/20000], Loss: 0.6393, Training Accuracy: 0.6140
# Epoch [5100/20000], Loss: 0.6389, Training Accuracy: 0.6135
# Epoch [5110/20000], Loss: 0.6392, Training Accuracy: 0.6170
# Epoch [5120/20000], Loss: 0.6390, Training Accuracy: 0.6125
# Epoch [5130/20000], Loss: 0.6389, Training Accuracy: 0.6115
# Epoch [5140/20000], Loss: 0.6389, Training Accuracy: 0.6190
# Epoch [5150/20000], Loss: 0.6394, Training Accuracy: 0.6105
# Epoch [5160/20000], Loss: 0.6390, Training Accuracy: 0.6130
# Epoch [5170/20000], Loss: 0.6389, Training Accuracy: 0.6115
# Epoch [5180/20000], Loss: 0.6390, Training Accuracy: 0.6185
# Epoch [5190/20000], Loss: 0.6389, Training Accuracy: 0.6125
# Epoch [5200/20000], Loss: 0.6391, Training Accuracy: 0.6130
# Epoch [5210/20000], Loss: 0.6390, Training Accuracy: 0.6130
# Epoch [5220/20000], Loss: 0.6391, Training Accuracy: 0.6160
# Epoch [5230/20000], Loss: 0.6389, Training Accuracy: 0.6135
# Epoch [5240/20000], Loss: 0.6391, Training Accuracy: 0.6130
# Epoch [5250/20000], Loss: 0.6389, Training Accuracy: 0.6130
# Epoch [5260/20000], Loss: 0.6390, Training Accuracy: 0.6160
# Epoch [5270/20000], Loss: 0.6391, Training Accuracy: 0.6160
# Epoch [5280/20000], Loss: 0.6389, Training Accuracy: 0.6135
# Epoch [5290/20000], Loss: 0.6392, Training Accuracy: 0.6125
# Epoch [5300/20000], Loss: 0.6389, Training Accuracy: 0.6170
# Epoch [5310/20000], Loss: 0.6389, Training Accuracy: 0.6160
# Epoch [5320/20000], Loss: 0.6391, Training Accuracy: 0.6125
# Epoch [5330/20000], Loss: 0.6388, Training Accuracy: 0.6110
# Epoch [5340/20000], Loss: 0.6390, Training Accuracy: 0.6150
# Epoch [5350/20000], Loss: 0.6388, Training Accuracy: 0.6150
# Epoch [5360/20000], Loss: 0.6389, Training Accuracy: 0.6145
# Epoch [5370/20000], Loss: 0.6396, Training Accuracy: 0.6140
# Epoch [5380/20000], Loss: 0.6391, Training Accuracy: 0.6165
# Epoch [5390/20000], Loss: 0.6389, Training Accuracy: 0.6145
# Epoch [5400/20000], Loss: 0.6388, Training Accuracy: 0.6105
# Epoch [5410/20000], Loss: 0.6388, Training Accuracy: 0.6165
# Epoch [5420/20000], Loss: 0.6388, Training Accuracy: 0.6125
# Epoch [5430/20000], Loss: 0.6391, Training Accuracy: 0.6140
# Epoch [5440/20000], Loss: 0.6389, Training Accuracy: 0.6110
# Epoch [5450/20000], Loss: 0.6390, Training Accuracy: 0.6160
# Epoch [5460/20000], Loss: 0.6388, Training Accuracy: 0.6130
# Epoch [5470/20000], Loss: 0.6388, Training Accuracy: 0.6135
# Epoch [5480/20000], Loss: 0.6388, Training Accuracy: 0.6120
# Epoch [5490/20000], Loss: 0.6390, Training Accuracy: 0.6140
# Epoch [5500/20000], Loss: 0.6390, Training Accuracy: 0.6155
# Epoch [5510/20000], Loss: 0.6389, Training Accuracy: 0.6195
# Epoch [5520/20000], Loss: 0.6388, Training Accuracy: 0.6155
# Epoch [5530/20000], Loss: 0.6388, Training Accuracy: 0.6190
# Epoch [5540/20000], Loss: 0.6388, Training Accuracy: 0.6120
# Epoch [5550/20000], Loss: 0.6388, Training Accuracy: 0.6145
# Epoch [5560/20000], Loss: 0.6388, Training Accuracy: 0.6155
# Epoch [5570/20000], Loss: 0.6390, Training Accuracy: 0.6145
# Epoch [5580/20000], Loss: 0.6390, Training Accuracy: 0.6140
# Epoch [5590/20000], Loss: 0.6391, Training Accuracy: 0.6165
# Epoch [5600/20000], Loss: 0.6389, Training Accuracy: 0.6130
# Epoch [5610/20000], Loss: 0.6388, Training Accuracy: 0.6160
# Epoch [5620/20000], Loss: 0.6387, Training Accuracy: 0.6140
# Epoch [5630/20000], Loss: 0.6388, Training Accuracy: 0.6120
# Epoch [5640/20000], Loss: 0.6389, Training Accuracy: 0.6130
# Epoch [5650/20000], Loss: 0.6387, Training Accuracy: 0.6125
# Epoch [5660/20000], Loss: 0.6389, Training Accuracy: 0.6130
# Epoch [5670/20000], Loss: 0.6389, Training Accuracy: 0.6140
# Epoch [5680/20000], Loss: 0.6389, Training Accuracy: 0.6170
# Epoch [5690/20000], Loss: 0.6387, Training Accuracy: 0.6135
# Epoch [5700/20000], Loss: 0.6389, Training Accuracy: 0.6135
# Epoch [5710/20000], Loss: 0.6387, Training Accuracy: 0.6155
# Epoch [5720/20000], Loss: 0.6388, Training Accuracy: 0.6160
# Epoch [5730/20000], Loss: 0.6389, Training Accuracy: 0.6160
# Epoch [5740/20000], Loss: 0.6387, Training Accuracy: 0.6135
# Epoch [5750/20000], Loss: 0.6389, Training Accuracy: 0.6130
# Epoch [5760/20000], Loss: 0.6387, Training Accuracy: 0.6135
# Epoch [5770/20000], Loss: 0.6387, Training Accuracy: 0.6150
# Epoch [5780/20000], Loss: 0.6390, Training Accuracy: 0.6140
# Epoch [5790/20000], Loss: 0.6387, Training Accuracy: 0.6130
# Epoch [5800/20000], Loss: 0.6388, Training Accuracy: 0.6165
# Epoch [5810/20000], Loss: 0.6386, Training Accuracy: 0.6135
# Epoch [5820/20000], Loss: 0.6387, Training Accuracy: 0.6130
# Epoch [5830/20000], Loss: 0.6387, Training Accuracy: 0.6145
# Epoch [5840/20000], Loss: 0.6388, Training Accuracy: 0.6130
# Epoch [5850/20000], Loss: 0.6390, Training Accuracy: 0.6130
# Epoch [5860/20000], Loss: 0.6389, Training Accuracy: 0.6145
# Epoch [5870/20000], Loss: 0.6387, Training Accuracy: 0.6140
# Epoch [5880/20000], Loss: 0.6386, Training Accuracy: 0.6130
# Epoch [5890/20000], Loss: 0.6386, Training Accuracy: 0.6190
# Epoch [5900/20000], Loss: 0.6387, Training Accuracy: 0.6155
# Epoch [5910/20000], Loss: 0.6389, Training Accuracy: 0.6170
# Epoch [5920/20000], Loss: 0.6386, Training Accuracy: 0.6165
# Epoch [5930/20000], Loss: 0.6386, Training Accuracy: 0.6140
# Epoch [5940/20000], Loss: 0.6393, Training Accuracy: 0.6160
# Epoch [5950/20000], Loss: 0.6387, Training Accuracy: 0.6170
# Epoch [5960/20000], Loss: 0.6387, Training Accuracy: 0.6145
# Epoch [5970/20000], Loss: 0.6386, Training Accuracy: 0.6155
# Epoch [5980/20000], Loss: 0.6385, Training Accuracy: 0.6115
# Epoch [5990/20000], Loss: 0.6386, Training Accuracy: 0.6130
# Epoch [6000/20000], Loss: 0.6385, Training Accuracy: 0.6130
# Epoch [6010/20000], Loss: 0.6386, Training Accuracy: 0.6140
# Epoch [6020/20000], Loss: 0.6388, Training Accuracy: 0.6130
# Epoch [6030/20000], Loss: 0.6385, Training Accuracy: 0.6220
# Epoch [6040/20000], Loss: 0.6389, Training Accuracy: 0.6155
# Epoch [6050/20000], Loss: 0.6385, Training Accuracy: 0.6115
# Epoch [6060/20000], Loss: 0.6387, Training Accuracy: 0.6120
# Epoch [6070/20000], Loss: 0.6385, Training Accuracy: 0.6145
# Epoch [6080/20000], Loss: 0.6385, Training Accuracy: 0.6160
# Epoch [6090/20000], Loss: 0.6387, Training Accuracy: 0.6130
# Epoch [6100/20000], Loss: 0.6390, Training Accuracy: 0.6150
# Epoch [6110/20000], Loss: 0.6385, Training Accuracy: 0.6140
# Epoch [6120/20000], Loss: 0.6385, Training Accuracy: 0.6165
# Epoch [6130/20000], Loss: 0.6385, Training Accuracy: 0.6150
# Epoch [6140/20000], Loss: 0.6385, Training Accuracy: 0.6185
# Epoch [6150/20000], Loss: 0.6385, Training Accuracy: 0.6145
# Epoch [6160/20000], Loss: 0.6385, Training Accuracy: 0.6155
# Epoch [6170/20000], Loss: 0.6385, Training Accuracy: 0.6140
# Epoch [6180/20000], Loss: 0.6385, Training Accuracy: 0.6155
# Epoch [6190/20000], Loss: 0.6389, Training Accuracy: 0.6135
# Epoch [6200/20000], Loss: 0.6385, Training Accuracy: 0.6135
# Epoch [6210/20000], Loss: 0.6386, Training Accuracy: 0.6160
# Epoch [6220/20000], Loss: 0.6385, Training Accuracy: 0.6155
# Epoch [6230/20000], Loss: 0.6386, Training Accuracy: 0.6145
# Epoch [6240/20000], Loss: 0.6384, Training Accuracy: 0.6130
# Epoch [6250/20000], Loss: 0.6387, Training Accuracy: 0.6135
# Epoch [6260/20000], Loss: 0.6387, Training Accuracy: 0.6150
# Epoch [6270/20000], Loss: 0.6387, Training Accuracy: 0.6155
# Epoch [6280/20000], Loss: 0.6385, Training Accuracy: 0.6150
# Epoch [6290/20000], Loss: 0.6384, Training Accuracy: 0.6185
# Epoch [6300/20000], Loss: 0.6384, Training Accuracy: 0.6200
# Epoch [6310/20000], Loss: 0.6385, Training Accuracy: 0.6135
# Epoch [6320/20000], Loss: 0.6385, Training Accuracy: 0.6160
# Epoch [6330/20000], Loss: 0.6384, Training Accuracy: 0.6205
# Epoch [6340/20000], Loss: 0.6387, Training Accuracy: 0.6135
# Epoch [6350/20000], Loss: 0.6385, Training Accuracy: 0.6190
# Epoch [6360/20000], Loss: 0.6386, Training Accuracy: 0.6150
# Epoch [6370/20000], Loss: 0.6384, Training Accuracy: 0.6200
# Epoch [6380/20000], Loss: 0.6385, Training Accuracy: 0.6130
# Epoch [6390/20000], Loss: 0.6383, Training Accuracy: 0.6165
# Epoch [6400/20000], Loss: 0.6383, Training Accuracy: 0.6200
# Epoch [6410/20000], Loss: 0.6391, Training Accuracy: 0.6115
# Epoch [6420/20000], Loss: 0.6385, Training Accuracy: 0.6145
# Epoch [6430/20000], Loss: 0.6384, Training Accuracy: 0.6130
# Epoch [6440/20000], Loss: 0.6383, Training Accuracy: 0.6140
# Epoch [6450/20000], Loss: 0.6383, Training Accuracy: 0.6115
# Epoch [6460/20000], Loss: 0.6383, Training Accuracy: 0.6150
# Epoch [6470/20000], Loss: 0.6383, Training Accuracy: 0.6200
# Epoch [6480/20000], Loss: 0.6384, Training Accuracy: 0.6145
# Epoch [6490/20000], Loss: 0.6386, Training Accuracy: 0.6140
# Epoch [6500/20000], Loss: 0.6383, Training Accuracy: 0.6145
# Epoch [6510/20000], Loss: 0.6383, Training Accuracy: 0.6145
# Epoch [6520/20000], Loss: 0.6388, Training Accuracy: 0.6150
# Epoch [6530/20000], Loss: 0.6383, Training Accuracy: 0.6150
# Epoch [6540/20000], Loss: 0.6384, Training Accuracy: 0.6170
# Epoch [6550/20000], Loss: 0.6383, Training Accuracy: 0.6140
# Epoch [6560/20000], Loss: 0.6385, Training Accuracy: 0.6155
# Epoch [6570/20000], Loss: 0.6384, Training Accuracy: 0.6160
# Epoch [6580/20000], Loss: 0.6382, Training Accuracy: 0.6125
# Epoch [6590/20000], Loss: 0.6383, Training Accuracy: 0.6160
# Epoch [6600/20000], Loss: 0.6392, Training Accuracy: 0.6105
# Epoch [6610/20000], Loss: 0.6386, Training Accuracy: 0.6145
# Epoch [6620/20000], Loss: 0.6384, Training Accuracy: 0.6155
# Epoch [6630/20000], Loss: 0.6383, Training Accuracy: 0.6155
# Epoch [6640/20000], Loss: 0.6382, Training Accuracy: 0.6145
# Epoch [6650/20000], Loss: 0.6382, Training Accuracy: 0.6160
# Epoch [6660/20000], Loss: 0.6384, Training Accuracy: 0.6170
# Epoch [6670/20000], Loss: 0.6384, Training Accuracy: 0.6145
# Epoch [6680/20000], Loss: 0.6382, Training Accuracy: 0.6155
# Epoch [6690/20000], Loss: 0.6386, Training Accuracy: 0.6140
# Epoch [6700/20000], Loss: 0.6382, Training Accuracy: 0.6130
# Epoch [6710/20000], Loss: 0.6384, Training Accuracy: 0.6165
# Epoch [6720/20000], Loss: 0.6382, Training Accuracy: 0.6205
# Epoch [6730/20000], Loss: 0.6382, Training Accuracy: 0.6170
# Epoch [6740/20000], Loss: 0.6385, Training Accuracy: 0.6140
# Epoch [6750/20000], Loss: 0.6381, Training Accuracy: 0.6115
# Epoch [6760/20000], Loss: 0.6383, Training Accuracy: 0.6145
# Epoch [6770/20000], Loss: 0.6385, Training Accuracy: 0.6175
# Epoch [6780/20000], Loss: 0.6384, Training Accuracy: 0.6150
# Epoch [6790/20000], Loss: 0.6381, Training Accuracy: 0.6150
# Epoch [6800/20000], Loss: 0.6383, Training Accuracy: 0.6140
# Epoch [6810/20000], Loss: 0.6382, Training Accuracy: 0.6175
# Epoch [6820/20000], Loss: 0.6382, Training Accuracy: 0.6140
# Epoch [6830/20000], Loss: 0.6386, Training Accuracy: 0.6170
# Epoch [6840/20000], Loss: 0.6386, Training Accuracy: 0.6160
# Epoch [6850/20000], Loss: 0.6401, Training Accuracy: 0.6160
# Epoch [6860/20000], Loss: 0.6385, Training Accuracy: 0.6165
# Epoch [6870/20000], Loss: 0.6381, Training Accuracy: 0.6150
# Epoch [6880/20000], Loss: 0.6381, Training Accuracy: 0.6160
# Epoch [6890/20000], Loss: 0.6381, Training Accuracy: 0.6170
# Epoch [6900/20000], Loss: 0.6381, Training Accuracy: 0.6145
# Epoch [6910/20000], Loss: 0.6381, Training Accuracy: 0.6130
# Epoch [6920/20000], Loss: 0.6381, Training Accuracy: 0.6135
# Epoch [6930/20000], Loss: 0.6381, Training Accuracy: 0.6120
# Epoch [6940/20000], Loss: 0.6380, Training Accuracy: 0.6110
# Epoch [6950/20000], Loss: 0.6380, Training Accuracy: 0.6115
# Epoch [6960/20000], Loss: 0.6380, Training Accuracy: 0.6100
# Epoch [6970/20000], Loss: 0.6380, Training Accuracy: 0.6100
# Epoch [6980/20000], Loss: 0.6380, Training Accuracy: 0.6120
# Epoch [6990/20000], Loss: 0.6380, Training Accuracy: 0.6105
# Epoch [7000/20000], Loss: 0.6380, Training Accuracy: 0.6135
# Epoch [7010/20000], Loss: 0.6380, Training Accuracy: 0.6160
# Epoch [7020/20000], Loss: 0.6380, Training Accuracy: 0.6170
# Epoch [7030/20000], Loss: 0.6381, Training Accuracy: 0.6190
# Epoch [7040/20000], Loss: 0.6382, Training Accuracy: 0.6160
# Epoch [7050/20000], Loss: 0.6380, Training Accuracy: 0.6170
# Epoch [7060/20000], Loss: 0.6381, Training Accuracy: 0.6185
# Epoch [7070/20000], Loss: 0.6387, Training Accuracy: 0.6150
# Epoch [7080/20000], Loss: 0.6384, Training Accuracy: 0.6175
# Epoch [7090/20000], Loss: 0.6382, Training Accuracy: 0.6165
# Epoch [7100/20000], Loss: 0.6380, Training Accuracy: 0.6160
# Epoch [7110/20000], Loss: 0.6379, Training Accuracy: 0.6145
# Epoch [7120/20000], Loss: 0.6380, Training Accuracy: 0.6155
# Epoch [7130/20000], Loss: 0.6381, Training Accuracy: 0.6195
# Epoch [7140/20000], Loss: 0.6380, Training Accuracy: 0.6160
# Epoch [7150/20000], Loss: 0.6381, Training Accuracy: 0.6180
# Epoch [7160/20000], Loss: 0.6382, Training Accuracy: 0.6165
# Epoch [7170/20000], Loss: 0.6379, Training Accuracy: 0.6130
# Epoch [7180/20000], Loss: 0.6381, Training Accuracy: 0.6180
# Epoch [7190/20000], Loss: 0.6384, Training Accuracy: 0.6140
# Epoch [7200/20000], Loss: 0.6381, Training Accuracy: 0.6165
# Epoch [7210/20000], Loss: 0.6379, Training Accuracy: 0.6110
# Epoch [7220/20000], Loss: 0.6380, Training Accuracy: 0.6175
# Epoch [7230/20000], Loss: 0.6380, Training Accuracy: 0.6170
# Epoch [7240/20000], Loss: 0.6379, Training Accuracy: 0.6155
# Epoch [7250/20000], Loss: 0.6384, Training Accuracy: 0.6150
# Epoch [7260/20000], Loss: 0.6379, Training Accuracy: 0.6125
# Epoch [7270/20000], Loss: 0.6381, Training Accuracy: 0.6175
# Epoch [7280/20000], Loss: 0.6379, Training Accuracy: 0.6140
# Epoch [7290/20000], Loss: 0.6380, Training Accuracy: 0.6160
# Epoch [7300/20000], Loss: 0.6379, Training Accuracy: 0.6160
# Epoch [7310/20000], Loss: 0.6380, Training Accuracy: 0.6170
# Epoch [7320/20000], Loss: 0.6381, Training Accuracy: 0.6170
# Epoch [7330/20000], Loss: 0.6380, Training Accuracy: 0.6190
# Epoch [7340/20000], Loss: 0.6380, Training Accuracy: 0.6160
# Epoch [7350/20000], Loss: 0.6378, Training Accuracy: 0.6125
# Epoch [7360/20000], Loss: 0.6379, Training Accuracy: 0.6175
# Epoch [7370/20000], Loss: 0.6389, Training Accuracy: 0.6115
# Epoch [7380/20000], Loss: 0.6383, Training Accuracy: 0.6165
# Epoch [7390/20000], Loss: 0.6380, Training Accuracy: 0.6150
# Epoch [7400/20000], Loss: 0.6379, Training Accuracy: 0.6170
# Epoch [7410/20000], Loss: 0.6378, Training Accuracy: 0.6135
# Epoch [7420/20000], Loss: 0.6378, Training Accuracy: 0.6165
# Epoch [7430/20000], Loss: 0.6379, Training Accuracy: 0.6165
# Epoch [7440/20000], Loss: 0.6379, Training Accuracy: 0.6155
# Epoch [7450/20000], Loss: 0.6380, Training Accuracy: 0.6150
# Epoch [7460/20000], Loss: 0.6378, Training Accuracy: 0.6165
# Epoch [7470/20000], Loss: 0.6378, Training Accuracy: 0.6150
# Epoch [7480/20000], Loss: 0.6384, Training Accuracy: 0.6155
# Epoch [7490/20000], Loss: 0.6379, Training Accuracy: 0.6180
# Epoch [7500/20000], Loss: 0.6377, Training Accuracy: 0.6130
# Epoch [7510/20000], Loss: 0.6379, Training Accuracy: 0.6150
# Epoch [7520/20000], Loss: 0.6377, Training Accuracy: 0.6175
# Epoch [7530/20000], Loss: 0.6378, Training Accuracy: 0.6150
# Epoch [7540/20000], Loss: 0.6380, Training Accuracy: 0.6165
# Epoch [7550/20000], Loss: 0.6377, Training Accuracy: 0.6140
# Epoch [7560/20000], Loss: 0.6378, Training Accuracy: 0.6175
# Epoch [7570/20000], Loss: 0.6387, Training Accuracy: 0.6165
# Epoch [7580/20000], Loss: 0.6382, Training Accuracy: 0.6150
# Epoch [7590/20000], Loss: 0.6379, Training Accuracy: 0.6185
# Epoch [7600/20000], Loss: 0.6377, Training Accuracy: 0.6165
# Epoch [7610/20000], Loss: 0.6376, Training Accuracy: 0.6145
# Epoch [7620/20000], Loss: 0.6377, Training Accuracy: 0.6165
# Epoch [7630/20000], Loss: 0.6376, Training Accuracy: 0.6125
# Epoch [7640/20000], Loss: 0.6377, Training Accuracy: 0.6165
# Epoch [7650/20000], Loss: 0.6383, Training Accuracy: 0.6170
# Epoch [7660/20000], Loss: 0.6377, Training Accuracy: 0.6165
# Epoch [7670/20000], Loss: 0.6378, Training Accuracy: 0.6160
# Epoch [7680/20000], Loss: 0.6378, Training Accuracy: 0.6205
# Epoch [7690/20000], Loss: 0.6377, Training Accuracy: 0.6170
# Epoch [7700/20000], Loss: 0.6376, Training Accuracy: 0.6155
# Epoch [7710/20000], Loss: 0.6376, Training Accuracy: 0.6175
# Epoch [7720/20000], Loss: 0.6387, Training Accuracy: 0.6160
# Epoch [7730/20000], Loss: 0.6378, Training Accuracy: 0.6135
# Epoch [7740/20000], Loss: 0.6377, Training Accuracy: 0.6185
# Epoch [7750/20000], Loss: 0.6377, Training Accuracy: 0.6165
# Epoch [7760/20000], Loss: 0.6376, Training Accuracy: 0.6180
# Epoch [7770/20000], Loss: 0.6376, Training Accuracy: 0.6195
# Epoch [7780/20000], Loss: 0.6375, Training Accuracy: 0.6180
# Epoch [7790/20000], Loss: 0.6378, Training Accuracy: 0.6145
# Epoch [7800/20000], Loss: 0.6377, Training Accuracy: 0.6165
# Epoch [7810/20000], Loss: 0.6376, Training Accuracy: 0.6175
# Epoch [7820/20000], Loss: 0.6378, Training Accuracy: 0.6180
# Epoch [7830/20000], Loss: 0.6375, Training Accuracy: 0.6140
# Epoch [7840/20000], Loss: 0.6376, Training Accuracy: 0.6180
# Epoch [7850/20000], Loss: 0.6385, Training Accuracy: 0.6175
# Epoch [7860/20000], Loss: 0.6378, Training Accuracy: 0.6170
# Epoch [7870/20000], Loss: 0.6375, Training Accuracy: 0.6190
# Epoch [7880/20000], Loss: 0.6376, Training Accuracy: 0.6185
# Epoch [7890/20000], Loss: 0.6376, Training Accuracy: 0.6150
# Epoch [7900/20000], Loss: 0.6377, Training Accuracy: 0.6150
# Epoch [7910/20000], Loss: 0.6375, Training Accuracy: 0.6210
# Epoch [7920/20000], Loss: 0.6378, Training Accuracy: 0.6135
# Epoch [7930/20000], Loss: 0.6376, Training Accuracy: 0.6160
# Epoch [7940/20000], Loss: 0.6378, Training Accuracy: 0.6180
# Epoch [7950/20000], Loss: 0.6374, Training Accuracy: 0.6140
# Epoch [7960/20000], Loss: 0.6377, Training Accuracy: 0.6120
# Epoch [7970/20000], Loss: 0.6375, Training Accuracy: 0.6185
# Epoch [7980/20000], Loss: 0.6375, Training Accuracy: 0.6185
# Epoch [7990/20000], Loss: 0.6381, Training Accuracy: 0.6165
# Epoch [8000/20000], Loss: 0.6375, Training Accuracy: 0.6150
# Epoch [8010/20000], Loss: 0.6376, Training Accuracy: 0.6160
# ...
# Epoch [17390/20000], Loss: 0.6334, Training Accuracy: 0.6190
# Epoch [17400/20000], Loss: 0.6331, Training Accuracy: 0.6180
# Epoch [17410/20000], Loss: 0.6334, Training Accuracy: 0.6195
# Epoch [17420/20000], Loss: 0.6338, Training Accuracy: 0.6185
# Epoch [17430/20000], Loss: 0.6331, Training Accuracy: 0.6235
# Epoch [17440/20000], Loss: 0.6335, Training Accuracy: 0.6200
# Epoch [17450/20000], Loss: 0.6333, Training Accuracy: 0.6210
# Epoch [17460/20000], Loss: 0.6331, Training Accuracy: 0.6160
# Epoch [17470/20000], Loss: 0.6334, Training Accuracy: 0.6190
# Epoch [17480/20000], Loss: 0.6343, Training Accuracy: 0.6185
# Epoch [17490/20000], Loss: 0.6334, Training Accuracy: 0.6215
# Epoch [17500/20000], Loss: 0.6331, Training Accuracy: 0.6225
# Epoch [17510/20000], Loss: 0.6333, Training Accuracy: 0.6165
# Epoch [17520/20000], Loss: 0.6333, Training Accuracy: 0.6175
# Epoch [17530/20000], Loss: 0.6331, Training Accuracy: 0.6205
# Epoch [17540/20000], Loss: 0.6331, Training Accuracy: 0.6200
# Epoch [17550/20000], Loss: 0.6335, Training Accuracy: 0.6190
# Epoch [17560/20000], Loss: 0.6344, Training Accuracy: 0.6205
# Epoch [17570/20000], Loss: 0.6333, Training Accuracy: 0.6230
# Epoch [17580/20000], Loss: 0.6331, Training Accuracy: 0.6200
# Epoch [17590/20000], Loss: 0.6331, Training Accuracy: 0.6235
# Epoch [17600/20000], Loss: 0.6332, Training Accuracy: 0.6195
# Epoch [17610/20000], Loss: 0.6331, Training Accuracy: 0.6220
# Epoch [17620/20000], Loss: 0.6332, Training Accuracy: 0.6210
# Epoch [17630/20000], Loss: 0.6331, Training Accuracy: 0.6215
# Epoch [17640/20000], Loss: 0.6331, Training Accuracy: 0.6225
# Epoch [17650/20000], Loss: 0.6340, Training Accuracy: 0.6135
# Epoch [17660/20000], Loss: 0.6331, Training Accuracy: 0.6240
# Epoch [17670/20000], Loss: 0.6334, Training Accuracy: 0.6165
# Epoch [17680/20000], Loss: 0.6333, Training Accuracy: 0.6195
# Epoch [17690/20000], Loss: 0.6331, Training Accuracy: 0.6215
# Epoch [17700/20000], Loss: 0.6331, Training Accuracy: 0.6195
# Epoch [17710/20000], Loss: 0.6336, Training Accuracy: 0.6190
# Epoch [17720/20000], Loss: 0.6333, Training Accuracy: 0.6160
# Epoch [17730/20000], Loss: 0.6331, Training Accuracy: 0.6215
# Epoch [17740/20000], Loss: 0.6336, Training Accuracy: 0.6200
# Epoch [17750/20000], Loss: 0.6331, Training Accuracy: 0.6225
# Epoch [17760/20000], Loss: 0.6331, Training Accuracy: 0.6190
# Epoch [17770/20000], Loss: 0.6337, Training Accuracy: 0.6180
# Epoch [17780/20000], Loss: 0.6331, Training Accuracy: 0.6200
# Epoch [17790/20000], Loss: 0.6332, Training Accuracy: 0.6180
# Epoch [17800/20000], Loss: 0.6335, Training Accuracy: 0.6200
# Epoch [17810/20000], Loss: 0.6330, Training Accuracy: 0.6215
# Epoch [17820/20000], Loss: 0.6331, Training Accuracy: 0.6200
# Epoch [17830/20000], Loss: 0.6341, Training Accuracy: 0.6180
# Epoch [17840/20000], Loss: 0.6330, Training Accuracy: 0.6210
# Epoch [17850/20000], Loss: 0.6334, Training Accuracy: 0.6195
# Epoch [17860/20000], Loss: 0.6331, Training Accuracy: 0.6180
# Epoch [17870/20000], Loss: 0.6332, Training Accuracy: 0.6170
# Epoch [17880/20000], Loss: 0.6330, Training Accuracy: 0.6195
# Epoch [17890/20000], Loss: 0.6330, Training Accuracy: 0.6180
# Epoch [17900/20000], Loss: 0.6338, Training Accuracy: 0.6175
# Epoch [17910/20000], Loss: 0.6332, Training Accuracy: 0.6185
# Epoch [17920/20000], Loss: 0.6332, Training Accuracy: 0.6210
# Epoch [17930/20000], Loss: 0.6332, Training Accuracy: 0.6185
# Epoch [17940/20000], Loss: 0.6332, Training Accuracy: 0.6195
# Epoch [17950/20000], Loss: 0.6330, Training Accuracy: 0.6175
# Epoch [17960/20000], Loss: 0.6332, Training Accuracy: 0.6160
# Epoch [17970/20000], Loss: 0.6330, Training Accuracy: 0.6190
# Epoch [17980/20000], Loss: 0.6330, Training Accuracy: 0.6180
# Epoch [17990/20000], Loss: 0.6336, Training Accuracy: 0.6200
# Epoch [18000/20000], Loss: 0.6335, Training Accuracy: 0.6160
# Epoch [18010/20000], Loss: 0.6336, Training Accuracy: 0.6170
# Epoch [18020/20000], Loss: 0.6331, Training Accuracy: 0.6155
# Epoch [18030/20000], Loss: 0.6331, Training Accuracy: 0.6195
# Epoch [18040/20000], Loss: 0.6330, Training Accuracy: 0.6220
# Epoch [18050/20000], Loss: 0.6334, Training Accuracy: 0.6205
# Epoch [18060/20000], Loss: 0.6334, Training Accuracy: 0.6225
# Epoch [18070/20000], Loss: 0.6329, Training Accuracy: 0.6245
# Epoch [18080/20000], Loss: 0.6331, Training Accuracy: 0.6185
# Epoch [18090/20000], Loss: 0.6342, Training Accuracy: 0.6185
# Epoch [18100/20000], Loss: 0.6331, Training Accuracy: 0.6190
# Epoch [18110/20000], Loss: 0.6330, Training Accuracy: 0.6225
# Epoch [18120/20000], Loss: 0.6331, Training Accuracy: 0.6165
# Epoch [18130/20000], Loss: 0.6331, Training Accuracy: 0.6165
# Epoch [18140/20000], Loss: 0.6330, Training Accuracy: 0.6175
# Epoch [18150/20000], Loss: 0.6331, Training Accuracy: 0.6175
# Epoch [18160/20000], Loss: 0.6339, Training Accuracy: 0.6185
# Epoch [18170/20000], Loss: 0.6329, Training Accuracy: 0.6225
# Epoch [18180/20000], Loss: 0.6334, Training Accuracy: 0.6195
# Epoch [18190/20000], Loss: 0.6329, Training Accuracy: 0.6225
# Epoch [18200/20000], Loss: 0.6331, Training Accuracy: 0.6170
# Epoch [18210/20000], Loss: 0.6337, Training Accuracy: 0.6205
# Epoch [18220/20000], Loss: 0.6329, Training Accuracy: 0.6215
# Epoch [18230/20000], Loss: 0.6331, Training Accuracy: 0.6220
# Epoch [18240/20000], Loss: 0.6332, Training Accuracy: 0.6205
# Epoch [18250/20000], Loss: 0.6329, Training Accuracy: 0.6235
# Epoch [18260/20000], Loss: 0.6330, Training Accuracy: 0.6205
# Epoch [18270/20000], Loss: 0.6343, Training Accuracy: 0.6145
# Epoch [18280/20000], Loss: 0.6329, Training Accuracy: 0.6195
# Epoch [18290/20000], Loss: 0.6330, Training Accuracy: 0.6200
# Epoch [18300/20000], Loss: 0.6331, Training Accuracy: 0.6200
# Epoch [18310/20000], Loss: 0.6329, Training Accuracy: 0.6205
# Epoch [18320/20000], Loss: 0.6328, Training Accuracy: 0.6250
# Epoch [18330/20000], Loss: 0.6330, Training Accuracy: 0.6195
# Epoch [18340/20000], Loss: 0.6348, Training Accuracy: 0.6175
# Epoch [18350/20000], Loss: 0.6336, Training Accuracy: 0.6185
# Epoch [18360/20000], Loss: 0.6330, Training Accuracy: 0.6220
# Epoch [18370/20000], Loss: 0.6328, Training Accuracy: 0.6190
# Epoch [18380/20000], Loss: 0.6330, Training Accuracy: 0.6165
# Epoch [18390/20000], Loss: 0.6329, Training Accuracy: 0.6165
# Epoch [18400/20000], Loss: 0.6329, Training Accuracy: 0.6180
# Epoch [18410/20000], Loss: 0.6333, Training Accuracy: 0.6185
# Epoch [18420/20000], Loss: 0.6331, Training Accuracy: 0.6180
# Epoch [18430/20000], Loss: 0.6328, Training Accuracy: 0.6185
# Epoch [18440/20000], Loss: 0.6328, Training Accuracy: 0.6170
# Epoch [18450/20000], Loss: 0.6347, Training Accuracy: 0.6175
# Epoch [18460/20000], Loss: 0.6331, Training Accuracy: 0.6165
# Epoch [18470/20000], Loss: 0.6329, Training Accuracy: 0.6175
# Epoch [18480/20000], Loss: 0.6328, Training Accuracy: 0.6215
# Epoch [18490/20000], Loss: 0.6328, Training Accuracy: 0.6240
# Epoch [18500/20000], Loss: 0.6330, Training Accuracy: 0.6155
# Epoch [18510/20000], Loss: 0.6328, Training Accuracy: 0.6260
# Epoch [18520/20000], Loss: 0.6330, Training Accuracy: 0.6210
# Epoch [18530/20000], Loss: 0.6331, Training Accuracy: 0.6195
# Epoch [18540/20000], Loss: 0.6328, Training Accuracy: 0.6215
# Epoch [18550/20000], Loss: 0.6328, Training Accuracy: 0.6220
# Epoch [18560/20000], Loss: 0.6337, Training Accuracy: 0.6145
# Epoch [18570/20000], Loss: 0.6329, Training Accuracy: 0.6245
# Epoch [18580/20000], Loss: 0.6335, Training Accuracy: 0.6185
# Epoch [18590/20000], Loss: 0.6329, Training Accuracy: 0.6215
# Epoch [18600/20000], Loss: 0.6328, Training Accuracy: 0.6175
# Epoch [18610/20000], Loss: 0.6328, Training Accuracy: 0.6175
# Epoch [18620/20000], Loss: 0.6328, Training Accuracy: 0.6215
# Epoch [18630/20000], Loss: 0.6329, Training Accuracy: 0.6210
# Epoch [18640/20000], Loss: 0.6334, Training Accuracy: 0.6195
# Epoch [18650/20000], Loss: 0.6328, Training Accuracy: 0.6225
# Epoch [18660/20000], Loss: 0.6331, Training Accuracy: 0.6185
# Epoch [18670/20000], Loss: 0.6333, Training Accuracy: 0.6195
# Epoch [18680/20000], Loss: 0.6327, Training Accuracy: 0.6210
# Epoch [18690/20000], Loss: 0.6331, Training Accuracy: 0.6190
# Epoch [18700/20000], Loss: 0.6334, Training Accuracy: 0.6185
# Epoch [18710/20000], Loss: 0.6329, Training Accuracy: 0.6160
# Epoch [18720/20000], Loss: 0.6330, Training Accuracy: 0.6155
# Epoch [18730/20000], Loss: 0.6328, Training Accuracy: 0.6170
# Epoch [18740/20000], Loss: 0.6329, Training Accuracy: 0.6175
# Epoch [18750/20000], Loss: 0.6341, Training Accuracy: 0.6195
# Epoch [18760/20000], Loss: 0.6328, Training Accuracy: 0.6210
# Epoch [18770/20000], Loss: 0.6330, Training Accuracy: 0.6225
# Epoch [18780/20000], Loss: 0.6328, Training Accuracy: 0.6190
# Epoch [18790/20000], Loss: 0.6330, Training Accuracy: 0.6165
# Epoch [18800/20000], Loss: 0.6329, Training Accuracy: 0.6165
# Epoch [18810/20000], Loss: 0.6328, Training Accuracy: 0.6190
# Epoch [18820/20000], Loss: 0.6333, Training Accuracy: 0.6190
# Epoch [18830/20000], Loss: 0.6334, Training Accuracy: 0.6195
# Epoch [18840/20000], Loss: 0.6332, Training Accuracy: 0.6215
# Epoch [18850/20000], Loss: 0.6328, Training Accuracy: 0.6175
# Epoch [18860/20000], Loss: 0.6328, Training Accuracy: 0.6195
# Epoch [18870/20000], Loss: 0.6327, Training Accuracy: 0.6265
# Epoch [18880/20000], Loss: 0.6329, Training Accuracy: 0.6190
# Epoch [18890/20000], Loss: 0.6340, Training Accuracy: 0.6150
# Epoch [18900/20000], Loss: 0.6330, Training Accuracy: 0.6190
# Epoch [18910/20000], Loss: 0.6327, Training Accuracy: 0.6185
# Epoch [18920/20000], Loss: 0.6330, Training Accuracy: 0.6205
# Epoch [18930/20000], Loss: 0.6327, Training Accuracy: 0.6245
# Epoch [18940/20000], Loss: 0.6327, Training Accuracy: 0.6185
# Epoch [18950/20000], Loss: 0.6336, Training Accuracy: 0.6195
# Epoch [18960/20000], Loss: 0.6328, Training Accuracy: 0.6160
# Epoch [18970/20000], Loss: 0.6331, Training Accuracy: 0.6200
# Epoch [18980/20000], Loss: 0.6327, Training Accuracy: 0.6170
# Epoch [18990/20000], Loss: 0.6328, Training Accuracy: 0.6185
# Epoch [19000/20000], Loss: 0.6327, Training Accuracy: 0.6175
# Epoch [19010/20000], Loss: 0.6330, Training Accuracy: 0.6180
# Epoch [19020/20000], Loss: 0.6337, Training Accuracy: 0.6200
# Epoch [19030/20000], Loss: 0.6330, Training Accuracy: 0.6200
# Epoch [19040/20000], Loss: 0.6326, Training Accuracy: 0.6240
# Epoch [19050/20000], Loss: 0.6329, Training Accuracy: 0.6170
# Epoch [19060/20000], Loss: 0.6328, Training Accuracy: 0.6180
# Epoch [19070/20000], Loss: 0.6328, Training Accuracy: 0.6175
# Epoch [19080/20000], Loss: 0.6331, Training Accuracy: 0.6180
# Epoch [19090/20000], Loss: 0.6330, Training Accuracy: 0.6210
# Epoch [19100/20000], Loss: 0.6341, Training Accuracy: 0.6170
# Epoch [19110/20000], Loss: 0.6334, Training Accuracy: 0.6180
# Epoch [19120/20000], Loss: 0.6328, Training Accuracy: 0.6170
# Epoch [19130/20000], Loss: 0.6326, Training Accuracy: 0.6170
# Epoch [19140/20000], Loss: 0.6326, Training Accuracy: 0.6255
# Epoch [19150/20000], Loss: 0.6326, Training Accuracy: 0.6255
# Epoch [19160/20000], Loss: 0.6326, Training Accuracy: 0.6210
# Epoch [19170/20000], Loss: 0.6326, Training Accuracy: 0.6250
# Epoch [19180/20000], Loss: 0.6326, Training Accuracy: 0.6230
# Epoch [19190/20000], Loss: 0.6325, Training Accuracy: 0.6240
# Epoch [19200/20000], Loss: 0.6325, Training Accuracy: 0.6175
# Epoch [19210/20000], Loss: 0.6325, Training Accuracy: 0.6220
# Epoch [19220/20000], Loss: 0.6325, Training Accuracy: 0.6255
# Epoch [19230/20000], Loss: 0.6326, Training Accuracy: 0.6205
# Epoch [19240/20000], Loss: 0.6325, Training Accuracy: 0.6265
# Epoch [19250/20000], Loss: 0.6325, Training Accuracy: 0.6225
# Epoch [19260/20000], Loss: 0.6329, Training Accuracy: 0.6190
# Epoch [19270/20000], Loss: 0.6327, Training Accuracy: 0.6235
# Epoch [19280/20000], Loss: 0.6325, Training Accuracy: 0.6205
# Epoch [19290/20000], Loss: 0.6330, Training Accuracy: 0.6205
# Epoch [19300/20000], Loss: 0.6332, Training Accuracy: 0.6205
# Epoch [19310/20000], Loss: 0.6328, Training Accuracy: 0.6205
# Epoch [19320/20000], Loss: 0.6325, Training Accuracy: 0.6190
# Epoch [19330/20000], Loss: 0.6326, Training Accuracy: 0.6225
# Epoch [19340/20000], Loss: 0.6331, Training Accuracy: 0.6200
# Epoch [19350/20000], Loss: 0.6328, Training Accuracy: 0.6215
# Epoch [19360/20000], Loss: 0.6325, Training Accuracy: 0.6200
# Epoch [19370/20000], Loss: 0.6328, Training Accuracy: 0.6175
# Epoch [19380/20000], Loss: 0.6338, Training Accuracy: 0.6200
# Epoch [19390/20000], Loss: 0.6326, Training Accuracy: 0.6235
# Epoch [19400/20000], Loss: 0.6326, Training Accuracy: 0.6200
# Epoch [19410/20000], Loss: 0.6329, Training Accuracy: 0.6190
# Epoch [19420/20000], Loss: 0.6329, Training Accuracy: 0.6190
# Epoch [19430/20000], Loss: 0.6327, Training Accuracy: 0.6200
# Epoch [19440/20000], Loss: 0.6326, Training Accuracy: 0.6230
# Epoch [19450/20000], Loss: 0.6325, Training Accuracy: 0.6235
# Epoch [19460/20000], Loss: 0.6325, Training Accuracy: 0.6210
# Epoch [19470/20000], Loss: 0.6336, Training Accuracy: 0.6150
# Epoch [19480/20000], Loss: 0.6325, Training Accuracy: 0.6205
# Epoch [19490/20000], Loss: 0.6328, Training Accuracy: 0.6155
# Epoch [19500/20000], Loss: 0.6327, Training Accuracy: 0.6220
# Epoch [19510/20000], Loss: 0.6324, Training Accuracy: 0.6235
# Epoch [19520/20000], Loss: 0.6326, Training Accuracy: 0.6160
# Epoch [19530/20000], Loss: 0.6330, Training Accuracy: 0.6185
# Epoch [19540/20000], Loss: 0.6326, Training Accuracy: 0.6195
# Epoch [19550/20000], Loss: 0.6324, Training Accuracy: 0.6230
# Epoch [19560/20000], Loss: 0.6326, Training Accuracy: 0.6150
# Epoch [19570/20000], Loss: 0.6343, Training Accuracy: 0.6195
# Epoch [19580/20000], Loss: 0.6327, Training Accuracy: 0.6180
# Epoch [19590/20000], Loss: 0.6324, Training Accuracy: 0.6200
# Epoch [19600/20000], Loss: 0.6326, Training Accuracy: 0.6170
# Epoch [19610/20000], Loss: 0.6325, Training Accuracy: 0.6200
# Epoch [19620/20000], Loss: 0.6326, Training Accuracy: 0.6220
# Epoch [19630/20000], Loss: 0.6326, Training Accuracy: 0.6230
# Epoch [19640/20000], Loss: 0.6326, Training Accuracy: 0.6220
# Epoch [19650/20000], Loss: 0.6327, Training Accuracy: 0.6225
# Epoch [19660/20000], Loss: 0.6329, Training Accuracy: 0.6200
# Epoch [19670/20000], Loss: 0.6328, Training Accuracy: 0.6225
# Epoch [19680/20000], Loss: 0.6324, Training Accuracy: 0.6205
# Epoch [19690/20000], Loss: 0.6332, Training Accuracy: 0.6195
# Epoch [19700/20000], Loss: 0.6326, Training Accuracy: 0.6180
# Epoch [19710/20000], Loss: 0.6328, Training Accuracy: 0.6195
# Epoch [19720/20000], Loss: 0.6324, Training Accuracy: 0.6195
# Epoch [19730/20000], Loss: 0.6326, Training Accuracy: 0.6170
# Epoch [19740/20000], Loss: 0.6328, Training Accuracy: 0.6200
# Epoch [19750/20000], Loss: 0.6324, Training Accuracy: 0.6215
# Epoch [19760/20000], Loss: 0.6325, Training Accuracy: 0.6220
# Epoch [19770/20000], Loss: 0.6341, Training Accuracy: 0.6180
# Epoch [19780/20000], Loss: 0.6326, Training Accuracy: 0.6190
# Epoch [19790/20000], Loss: 0.6324, Training Accuracy: 0.6245
# Epoch [19800/20000], Loss: 0.6326, Training Accuracy: 0.6210
# Epoch [19810/20000], Loss: 0.6324, Training Accuracy: 0.6145
# Epoch [19820/20000], Loss: 0.6327, Training Accuracy: 0.6195
# Epoch [19830/20000], Loss: 0.6325, Training Accuracy: 0.6180
# Epoch [19840/20000], Loss: 0.6323, Training Accuracy: 0.6255
# Epoch [19850/20000], Loss: 0.6324, Training Accuracy: 0.6225
# Epoch [19860/20000], Loss: 0.6345, Training Accuracy: 0.6130
# Epoch [19870/20000], Loss: 0.6328, Training Accuracy: 0.6185
# Epoch [19880/20000], Loss: 0.6324, Training Accuracy: 0.6225
# Epoch [19890/20000], Loss: 0.6323, Training Accuracy: 0.6205
# Epoch [19900/20000], Loss: 0.6324, Training Accuracy: 0.6170
# Epoch [19910/20000], Loss: 0.6323, Training Accuracy: 0.6155
# Epoch [19920/20000], Loss: 0.6323, Training Accuracy: 0.6165
# Epoch [19930/20000], Loss: 0.6330, Training Accuracy: 0.6190
# Epoch [19940/20000], Loss: 0.6329, Training Accuracy: 0.6145
# Epoch [19950/20000], Loss: 0.6328, Training Accuracy: 0.6180
# Epoch [19960/20000], Loss: 0.6323, Training Accuracy: 0.6160
# Epoch [19970/20000], Loss: 0.6326, Training Accuracy: 0.6160
# Epoch [19980/20000], Loss: 0.6323, Training Accuracy: 0.6245
# Epoch [19990/20000], Loss: 0.6324, Training Accuracy: 0.6215
# Epoch [20000/20000], Loss: 0.6337, Training Accuracy: 0.6165

# %% [markdown]
# ## Uncomment next cell if you want to load a particular model you already trained.

# %%
# loaded_model = SimpleDenseNet(input_dim=len(list(features_to_extract.keys())), hidden_dim=512).to(device)
# loaded_model.load_state_dict(torch.load('llama-' + task + '-best-model'))

# # Set the model to evaluation mode"
# loaded_model.eval()

# %% [markdown]
# #Compute the metrics using the model on the Test Set.

# %%
X_test_tensor = torch.tensor(X_test_features, dtype=torch.float32).to(device)
Y_test_tensor = torch.tensor(Y_test, dtype=torch.float32).view(-1, 1).to(device)

test_metrics = compute_metrics(denseModel, X_test_tensor, Y_test_tensor)

print(
    f"Testing - Accuracy: {test_metrics['Accuracy']:.4f}, Precision: {test_metrics['Precision']:.4f}, Recall: {test_metrics['Recall']:.4f}, F1: {test_metrics['F1']:.4f}, ROC AUC: {test_metrics['ROC AUC']:.4f}, PR AUC: {test_metrics['PR AUC']:.4f}"
)
print(
    f"Testing - Negative: {test_metrics['Accuracy']:.4f}, Precision-Negative: {test_metrics['Precision-Negative']:.4f}, Recall-Negative: {test_metrics['Recall-Negative']:.4f}, F1-Negative: {test_metrics['F1-Negative']:.4f}, ROC AUC-Negative: {test_metrics['ROC AUC-Negative']:.4f}, PR AUC-Negative: {test_metrics['PR AUC-Negative']:.4f}"
)
# Out:
# Testing - Accuracy: 0.5958, Precision: 0.6106, Recall: 0.5288, F1: 0.5668, ROC AUC: 0.6301, PR AUC: 0.6875
# Testing - Negative: 0.5958, Precision-Negative: 0.5845, Recall-Negative: 0.6628, F1-Negative: 0.6212, ROC AUC-Negative: 0.3699, PR AUC-Negative: 0.5290

# %% [markdown]
# ## Save the results on a CSV if you want.

# %%
model_dataframe = pd.DataFrame(
    columns=[
        "features",
        "model_name",
        "feature_to_extract",
        "method",
        "accuracy",
        "precision",
        "recall",
        "roc auc",
        "pr auc",
        "negative",
        "precision-negative",
        "recall-negative",
        "negative f1",
        "lr_accuracy",
        "lr_features_log",
        "lr_features_no_log",
    ]
)

# %%
d = {
    "features": features_to_extract,
    "model_name": str(model.getName()),
    "feature_to_extract": feature_to_extract,
    "method": "TEST",
    "accuracy": test_metrics["Accuracy"],
    "precision": test_metrics["Precision"],
    "recall": test_metrics["Recall"],
    "f1": test_metrics["F1"],
    "pr auc": test_metrics["PR AUC"],
    "precision-negative": test_metrics["Precision-Negative"],
    "recall-negative": test_metrics["Recall-Negative"],
    "negative-f1": test_metrics["F1-Negative"],
    "lr_accuracy": lr_accuracy,
    "lr_features_log": lr_features_log,
    "lr_features_no_log": lr_features_no_log,
}

model_dataframe.loc[len(model_dataframe.index)] = d

# %%
model_dataframe.head()
# Out:
#                                             features               model_name  \
# 0  {'mtp': True, 'avgtp': False, 'MDVTP': False, ...  facebook/bart-large-cnn
#
#   method  accuracy  precision    recall  roc auc    pr auc  negative  \
# 0   TEST  0.595778   0.610598  0.528778      NaN  0.687493       NaN
#
#    precision-negative  recall-negative  negative f1  lr_accuracy  \
# 0             0.58446         0.662778          NaN     0.541889
#
#                lr_features_log            lr_features_no_log
# 0  {'mtp': -0.917627619300086}  {'mtp': 0.39946560232398703}

# %%
csv_name = f"{model.getSanitizedName()}_{task}_{includeKnowledge=}_{includeConditioned=}_{'_'.join([f'{k}={v}' for k, v in features_to_extract.items()])}.csv"
model_dataframe.to_csv(output_path / csv_name, index=False)
